# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import scipy.stats as st

# %% [markdown]
# # Data Cleaning
# ## Live Demos

# %%
jobs_data = pd.read_csv("data/ai-market-trends/ai_job_dataset.csv")

# %%
jobs_data1 = pd.read_csv("data/ai-market-trends/ai_job_dataset1.csv")

# %%
set(jobs_data.job_id).symmetric_difference(set(jobs_data1.job_id))
# Out:
# set()

# %%
jobs_data.columns, jobs_data1.columns
# Out:
# (Index(['job_id', 'job_title', 'salary_usd', 'salary_currency',
#         'experience_level', 'employment_type', 'company_location',
#         'company_size', 'employee_residence', 'remote_ratio', 'required_skills',
#         'education_required', 'years_experience', 'industry', 'posting_date',
#         'application_deadline', 'job_description_length', 'benefits_score',
#         'company_name'],
#        dtype='object'),
#  Index(['job_id', 'job_title', 'salary_usd', 'salary_currency', 'salary_local',
#         'experience_level', 'employment_type', 'company_location',
#         'company_size', 'employee_residence', 'remote_ratio', 'required_skills',
#         'education_required', 'years_experience', 'industry', 'posting_date',
#         'application_deadline', 'job_description_length', 'benefits_score',
#         'company_name'],
#        dtype='object'))

# %%
jobs_data[jobs_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [job_id, job_title, salary_usd, salary_currency, experience_level, employment_type, company_location, company_size, employee_residence, remote_ratio, required_skills, education_required, years_experience, industry, posting_date, application_deadline, job_description_length, benefits_score, company_name]
# Index: []

# %% [markdown]
# there are not duplicated records (meaning all their fields are the same) because each and every record has its own unique id

# %%
jobs_data[jobs_data.duplicated("job_title")
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 7      AI00008                 NLP Engineer       70640             EUR
# 9      AI00010         AI Software Engineer      102557             USD
# 11     AI00012                 AI Architect      115047             USD
# 12     AI00013                AI Consultant      124355             EUR
# 13     AI00014  Autonomous Systems Engineer       68760             USD
# ...        ...                          ...         ...             ...
# 14995  AI14996            Robotics Engineer       38604             USD
# 14996  AI14997  Machine Learning Researcher       57811             GBP
# 14997  AI14998                 NLP Engineer      189490             USD
# 14998  AI14999                   Head of AI       79461             EUR
# 14999  AI15000     Computer Vision Engineer       56481             USD
#
#       experience_level employment_type company_location company_size  \
# ...

# %%
jobs_data.drop_duplicates(["job_title", "salary_usd"])
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 0      AI00001        AI Research Scientist       90376             USD
# 1      AI00002         AI Software Engineer       61895             USD
# 2      AI00003                AI Specialist      152626             USD
# 3      AI00004                 NLP Engineer       80215             USD
# 4      AI00005                AI Consultant       54624             EUR
# ...        ...                          ...         ...             ...
# 14995  AI14996            Robotics Engineer       38604             USD
# 14996  AI14997  Machine Learning Researcher       57811             GBP
# 14997  AI14998                 NLP Engineer      189490             USD
# 14998  AI14999                   Head of AI       79461             EUR
# 14999  AI15000     Computer Vision Engineer       56481             USD
#
#       experience_level employment_type company_location company_size  \
# ...

# %%
jobs_data.shape
# Out:
# (15000, 19)

# %%
jobs_data.dtypes
# Out:
# job_id                     object
# job_title                  object
# salary_usd                  int64
# salary_currency            object
# experience_level           object
# employment_type            object
# company_location           object
# company_size               object
# employee_residence         object
# remote_ratio                int64
# required_skills            object
# education_required         object
# years_experience            int64
# industry                   object
# posting_date               object
# application_deadline       object
# job_description_length      int64
# benefits_score            float64
# company_name               object
# dtype: object

# %%
jobs_data.head(10)
# Out:
#     job_id                 job_title  salary_usd salary_currency  \
# 0  AI00001     AI Research Scientist       90376             USD
# 1  AI00002      AI Software Engineer       61895             USD
# 2  AI00003             AI Specialist      152626             USD
# 3  AI00004              NLP Engineer       80215             USD
# 4  AI00005             AI Consultant       54624             EUR
# 5  AI00006              AI Architect      123574             EUR
# 6  AI00007  Principal Data Scientist       79670             GBP
# 7  AI00008              NLP Engineer       70640             EUR
# 8  AI00009              Data Analyst      160710             USD
# 9  AI00010      AI Software Engineer      102557             USD
#
#   experience_level employment_type company_location company_size  \
# 0               SE              CT            China            M
# 1               EN              CT           Canada            M
# ...

# %%
jobs_data.sample(20)
# Out:
#         job_id                 job_title  salary_usd salary_currency  \
# 12938  AI12939              AI Architect       58147             USD
# 4086   AI04087            Data Scientist       56585             USD
# 5750   AI05751     AI Research Scientist       74149             USD
# 10800  AI10801         Robotics Engineer      139252             USD
# 8186   AI08187        Research Scientist      130341             USD
# 12798  AI12799             AI Specialist      270238             USD
# 7795   AI07796  Principal Data Scientist       92753             USD
# 14319  AI14320     AI Research Scientist       73776             USD
# 6021   AI06022              AI Architect      132228             EUR
# 4530   AI04531           ML Ops Engineer       62554             USD
# 9517   AI09518           ML Ops Engineer      101197             USD
# 13871  AI13872             AI Consultant      148515             USD
# 14684  AI14685                Head of AI       85131             USD
# ...

# %%
jobs_data.job_id.nunique()
# Out:
# 15000

# %%
jobs_data.job_id.nunique() == len(jobs_data)
# Out:
# True

# %%
jobs_data.set_index("job_id")
# Out:
#                            job_title  salary_usd salary_currency  \
# job_id
# AI00001        AI Research Scientist       90376             USD
# AI00002         AI Software Engineer       61895             USD
# AI00003                AI Specialist      152626             USD
# AI00004                 NLP Engineer       80215             USD
# AI00005                AI Consultant       54624             EUR
# ...                              ...         ...             ...
# AI14996            Robotics Engineer       38604             USD
# AI14997  Machine Learning Researcher       57811             GBP
# AI14998                 NLP Engineer      189490             USD
# AI14999                   Head of AI       79461             EUR
# AI15000     Computer Vision Engineer       56481             USD
#
#         experience_level employment_type company_location company_size  \
# job_id
# AI00001               SE              CT            China            M
# ...

# %% [markdown]
# the column job_id has a big entropy so it won't be good for modelling. Instead it can be useful for referring to data

# %%
jobs_data[
    jobs_data.job_id == "AI05713"
]
# Out:
#        job_id              job_title  salary_usd salary_currency  \
# 5712  AI05713  AI Research Scientist       54940             USD
#
#      experience_level employment_type company_location company_size  \
# 5712               EN              PT          Austria            M
#
#      employee_residence  remote_ratio      required_skills education_required  \
# 5712            Austria            50  SQL, Linux, PyTorch          Associate
#
#       years_experience   industry posting_date application_deadline  \
# 5712                 1  Education   2024-06-02           2024-06-29
#
#       job_description_length  benefits_score                company_name
# 5712                    1014             5.1  Digital Transformation LLC

# %%
jobs_data.salary_currency.value_counts(dropna = False)
# Out:
# salary_currency
# USD    11957
# EUR     2314
# GBP      729
# Name: count, dtype: int64

# %% [markdown]
# value_counts() drops values that are NaN

# %%
jobs_data.company_location.value_counts()
# Out:
# company_location
# Germany           814
# Denmark           778
# Canada            769
# France            769
# Austria           765
# Singapore         764
# China             763
# India             754
# Sweden            752
# Israel            751
# Ireland           750
# Switzerland       746
# Japan             733
# Finland           733
# Australia         732
# Netherlands       731
# United Kingdom    729
# United States     724
# South Korea       722
# Norway            721
# Name: count, dtype: int64

# %%
jobs_data.remote_ratio.value_counts()
# Out:
# remote_ratio
# 0      5075
# 50     5005
# 100    4920
# Name: count, dtype: int64

# %%
jobs_data.remote_ratio = jobs_data.remote_ratio.replace({0: "Onsite", 50: "Hybrid", 100: "Remote"})

# %%
jobs_data.remote_ratio
# Out:
# 0        Hybrid
# 1        Remote
# 2        Onsite
# 3        Hybrid
# 4        Remote
#           ...
# 14995    Hybrid
# 14996    Onsite
# 14997    Hybrid
# 14998    Onsite
# 14999    Hybrid
# Name: remote_ratio, Length: 15000, dtype: object

# %%
jobs_data.experience_level = jobs_data.experience_level.astype("category")

# %%
jobs_data.experience_level.value_counts()
# Out:
# experience_level
# MI    3781
# EX    3760
# SE    3741
# EN    3718
# Name: count, dtype: int64

# %%
jobs_data.pivot_table(columns = "experience_level", index = "company_size", aggfunc = "size")
# Out:
# C:\Users\aneli\AppData\Local\Temp\ipykernel_7052\210351302.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   jobs_data.pivot_table(columns = "experience_level", index = "company_size", aggfunc = "size")
# experience_level    EN    EX    MI    SE
# company_size
# L                 1214  1201  1284  1299
# M                 1237  1263  1277  1218
# S                 1267  1296  1220  1224

# %%
st.chi2_contingency(jobs_data.pivot_table(columns = "experience_level", index = "company_size", aggfunc = "size"))
# Out:
# C:\Users\aneli\AppData\Local\Temp\ipykernel_7052\1856348833.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   st.chi2_contingency(jobs_data.pivot_table(columns = "experience_level", index = "company_size", aggfunc = "size"))
# Chi2ContingencyResult(statistic=np.float64(10.056921001575674), pvalue=np.float64(0.12227532866081985), dof=6, expected_freq=array([[1238.8376, 1252.832 , 1259.8292, 1246.5012],
#        [1238.094 , 1252.08  , 1259.073 , 1245.753 ],
#        [1241.0684, 1255.088 , 1262.0978, 1248.7458]]))

# %%
jobs_data.job_title.value_counts()
# Out:
# job_title
# Machine Learning Researcher    808
# AI Software Engineer           784
# Autonomous Systems Engineer    777
# Machine Learning Engineer      772
# AI Architect                   771
# Head of AI                     765
# NLP Engineer                   762
# Robotics Engineer              759
# Data Analyst                   759
# AI Research Scientist          756
# Data Engineer                  749
# AI Product Manager             743
# Research Scientist             742
# Principal Data Scientist       734
# AI Specialist                  728
# ML Ops Engineer                725
# Computer Vision Engineer       724
# Data Scientist                 720
# Deep Learning Engineer         718
# AI Consultant                  704
# Name: count, dtype: int64

# %%
jobs_data[jobs_data.job_title == "Head of AI"].company_size.value_counts()
# Out:
# company_size
# M    283
# L    246
# S    236
# Name: count, dtype: int64

# %%
jobs_data[jobs_data.job_title == "Machine Learning Researcher"].company_size.value_counts()
# Out:
# company_size
# S    293
# M    270
# L    245
# Name: count, dtype: int64

# %%
jobs_data.posting_date = pd.to_datetime(jobs_data.posting_date)

# %%
jobs_data.posting_date
# Out:
# 0       2024-10-18
# 1       2024-11-20
# 2       2025-03-18
# 3       2024-12-23
# 4       2025-04-15
#            ...
# 14995   2025-02-06
# 14996   2024-10-16
# 14997   2024-03-19
# 14998   2024-03-22
# 14999   2024-07-18
# Name: posting_date, Length: 15000, dtype: datetime64[ns]

# %%
jobs_data.application_deadline = pd.to_datetime(jobs_data.application_deadline)

# %%
jobs_data["days_left_to_apply"] = jobs_data.application_deadline - jobs_data.posting_date

# %%
jobs_data.days_left_to_apply.value_counts()
# Out:
# days_left_to_apply
# 66 days    283
# 60 days    277
# 58 days    276
# 39 days    273
# 27 days    268
#           ...
# 19 days    229
# 64 days    227
# 23 days    222
# 43 days    201
# 74 days      2
# Name: count, Length: 61, dtype: int64

# %%
plt.hist(jobs_data.days_left_to_apply.dt.days / 7, bins = 20)
plt.show()

# %%
jobs_data.days_left_to_apply.dt.days.describe()
# Out:
# count    15000.000000
# mean        43.546200
# std         17.325134
# min         14.000000
# 25%         29.000000
# 50%         44.000000
# 75%         59.000000
# max         74.000000
# Name: days_left_to_apply, dtype: float64

# %%
skills = jobs_data.required_skills.str.split(", ", expand = True)

# %%
skills
# Out:
#                    0                1              2              3  \
# 0            Tableau          PyTorch     Kubernetes          Linux
# 1      Deep Learning              AWS    Mathematics         Python
# 2         Kubernetes    Deep Learning           Java         Hadoop
# 3              Scala              SQL          Linux         Python
# 4              MLOps             Java        Tableau         Python
# ...              ...              ...            ...            ...
# 14995           Java       Kubernetes          Azure           None
# 14996    Mathematics           Docker            SQL  Deep Learning
# 14997          Scala            Spark            NLP           None
# 14998           Java  Computer Vision         Python     TensorFlow
# 14999          Scala            Azure  Deep Learning            GCP
#
#                  4
# 0              NLP
# 1           Docker
# 2              NLP
# 3             None
# 4             None
# ...            ...
# ...

# %%
skills[skills[3] == "Deep Learning"]
# Out:
#                  0           1                2              3        4
# 98          Python         AWS       Kubernetes  Deep Learning     None
# 116     Kubernetes         SQL            Azure  Deep Learning    Linux
# 128            GCP           R            Azure  Deep Learning  PyTorch
# 139          Linux         AWS  Computer Vision  Deep Learning     None
# 141            GCP  Kubernetes  Computer Vision  Deep Learning      SQL
# ...            ...         ...              ...            ...      ...
# 14854          SQL  TensorFlow  Computer Vision  Deep Learning   Python
# 14862       Python        Java          Tableau  Deep Learning     None
# 14934            R  Statistics           Docker  Deep Learning     None
# 14972        Linux         AWS          PyTorch  Deep Learning  Tableau
# 14996  Mathematics      Docker              SQL  Deep Learning     None
#
# [491 rows x 5 columns]

# %%
skills[skills[0] == "Deep Learning"].index
# Out:
# Index([    1,    20,    30,    48,    50,    97,   162,   179,   284,   303,
#        ...
#        14611, 14614, 14653, 14669, 14731, 14753, 14761, 14797, 14849, 14889],
#       dtype='int64', length=411)

# %%
jobs_data.loc[skills[skills[0] == "Deep Learning"].index]
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 1      AI00002         AI Software Engineer       61895             USD
# 20     AI00021                Data Engineer      134197             USD
# 30     AI00031                   Head of AI       67488             EUR
# 48     AI00049                AI Specialist      288815             USD
# 50     AI00051                 AI Architect       70391             EUR
# ...        ...                          ...         ...             ...
# 14753  AI14754                Data Engineer      108907             USD
# 14761  AI14762           AI Product Manager      111106             GBP
# 14797  AI14798                   Head of AI      206490             USD
# 14849  AI14850  Autonomous Systems Engineer      160590             EUR
# 14889  AI14890               Data Scientist       39076             USD
#
#       experience_level employment_type company_location company_size  \
# ...

# %%
jobs_data[jobs_data.required_skills.str.contains("deep learning", case = False)]
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 1      AI00002         AI Software Engineer       61895             USD
# 2      AI00003                AI Specialist      152626             USD
# 15     AI00016           AI Product Manager       78846             GBP
# 20     AI00021                Data Engineer      134197             USD
# 30     AI00031                   Head of AI       67488             EUR
# ...        ...                          ...         ...             ...
# 14980  AI14981        AI Research Scientist       54209             USD
# 14992  AI14993  Autonomous Systems Engineer      200047             USD
# 14993  AI14994  Autonomous Systems Engineer      130671             USD
# 14996  AI14997  Machine Learning Researcher       57811             GBP
# 14999  AI15000     Computer Vision Engineer       56481             USD
#
#       experience_level employment_type company_location company_size  \
# ...

# %%
jobs_data[jobs_data.required_skills.str.contains("deep learning", case = False)].job_title.value_counts()
# Out:
# job_title
# NLP Engineer                   125
# Data Engineer                  123
# Head of AI                     120
# AI Software Engineer           120
# Research Scientist             119
# Data Scientist                 116
# Machine Learning Researcher    115
# Data Analyst                   113
# AI Consultant                  112
# Computer Vision Engineer       112
# AI Research Scientist          112
# Principal Data Scientist       110
# Autonomous Systems Engineer    104
# AI Product Manager             104
# Machine Learning Engineer      104
# AI Specialist                  102
# AI Architect                   100
# Robotics Engineer               96
# Deep Learning Engineer          94
# ML Ops Engineer                 88
# Name: count, dtype: int64
