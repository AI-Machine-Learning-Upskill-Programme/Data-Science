# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Tidying and Cleaning Demos 2
# ## Live Demos

# %%
religion_data = pd.read_csv("02.Data-Tidying-and-Cleaning-Materials/pew.csv")

# %%
religion_data
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
religion_data["$50-75k"]
# Out:
# 0      137
# 1       70
# 2       58
# 3     1116
# 4       35
# 5     1486
# 6       34
# 7      223
# 8       30
# 9       95
# 10    1107
# 11     112
# 12      23
# 13      47
# 14      14
# 15      63
# 16       7
# 17     528
# Name: $50-75k, dtype: int64

# %%
religion_data = religion_data.melt(id_vars = ["religion"], var_name = "income", value_name = "frequency")

# %%
religion_data
# Out:
#                   religion              income  frequency
# 0                 Agnostic               <$10k         27
# 1                  Atheist               <$10k         12
# 2                 Buddhist               <$10k         27
# 3                 Catholic               <$10k        418
# 4       Don’t know/refused               <$10k         15
# ..                     ...                 ...        ...
# 175               Orthodox  Don't know/refused         73
# 176        Other Christian  Don't know/refused         18
# 177           Other Faiths  Don't know/refused         71
# 178  Other World Religions  Don't know/refused          8
# 179           Unaffiliated  Don't know/refused        597
#
# [180 rows x 3 columns]

# %%
tb_data = pd.read_csv("02.Data-Tidying-and-Cleaning-Materials/tb.csv")

# %%
tb_data
# Out:
#      iso2  year  m04   m514   m014  m1524   m2534   m3544   m4554  m5564  ...  \
# 0      AD  1989  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN  ...
# 1      AD  1990  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN  ...
# 2      AD  1991  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN  ...
# 3      AD  1992  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN  ...
# 4      AD  1993  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN  ...
# ...   ...   ...  ...    ...    ...    ...     ...     ...     ...    ...  ...
# 5764   ZW  2004  NaN    NaN  187.0  833.0  2908.0  2298.0  1056.0  366.0  ...
# 5765   ZW  2005  NaN    NaN  210.0  837.0  2264.0  1855.0   762.0  295.0  ...
# 5766   ZW  2006  NaN    NaN  215.0  736.0  2391.0  1939.0   896.0  348.0  ...
# 5767   ZW  2007  6.0  132.0  138.0  500.0  3693.0     0.0   716.0  292.0  ...
# 5768   ZW  2008  NaN    NaN  127.0  614.0     0.0  3316.0   704.0  263.0  ...
#
# ...

# %% [markdown]
# It is not okay to replace NaN with 0 but here is how it happens

# %%
tb_data.fillna(0)

# %%
tb_data.columns
# Out:
# Index(['iso2', 'year', 'm04', 'm514', 'm014', 'm1524', 'm2534', 'm3544',
#        'm4554', 'm5564', 'm65', 'mu', 'f04', 'f514', 'f014', 'f1524', 'f2534',
#        'f3544', 'f4554', 'f5564', 'f65', 'fu'],
#       dtype='object')

# %%
tb_data_processed = tb_data.melt(id_vars = ["iso2", "year"])

# %%
tb_data_processed
# Out:
#        iso2  year variable  value
# 0        AD  1989      m04    NaN
# 1        AD  1990      m04    NaN
# 2        AD  1991      m04    NaN
# 3        AD  1992      m04    NaN
# 4        AD  1993      m04    NaN
# ...     ...   ...      ...    ...
# 115375   ZW  2004       fu    NaN
# 115376   ZW  2005       fu    NaN
# 115377   ZW  2006       fu    NaN
# 115378   ZW  2007       fu    NaN
# 115379   ZW  2008       fu    0.0
#
# [115380 rows x 4 columns]

# %%
tb_data_processed.dropna()
# Out:
#        iso2  year variable  value
# 15       AD  2005      m04    0.0
# 16       AD  2006      m04    0.0
# 18       AD  2008      m04    0.0
# 42       AE  2006      m04    0.0
# 43       AE  2007      m04    0.0
# ...     ...   ...      ...    ...
# 115195   VU  2008       fu    0.0
# 115269   YE  2008       fu    0.0
# 115323   ZA  2008       fu    0.0
# 115350   ZM  2008       fu    0.0
# 115379   ZW  2008       fu    0.0
#
# [35552 rows x 4 columns]

# %%
tb_data_processed.fillna(-1)
# Out:
#        iso2  year variable  value
# 0        AD  1989      m04   -1.0
# 1        AD  1990      m04   -1.0
# 2        AD  1991      m04   -1.0
# 3        AD  1992      m04   -1.0
# 4        AD  1993      m04   -1.0
# ...     ...   ...      ...    ...
# 115375   ZW  2004       fu   -1.0
# 115376   ZW  2005       fu   -1.0
# 115377   ZW  2006       fu   -1.0
# 115378   ZW  2007       fu   -1.0
# 115379   ZW  2008       fu    0.0
#
# [115380 rows x 4 columns]

# %%
tb_data_processed.variable[0]
# Out:
# 'm04'

# %%
tb_data_processed.variable.str.slice(0, 1).unique()
# Out:
# array(['m', 'f'], dtype=object)

# %%
tb_data_processed.variable.str.slice(0, 1).value_counts()
# Out:
# variable
# m    57690
# f    57690
# Name: count, dtype: int64

# %%
tb_data_processed.variable.str.slice(1)
# Out:
# 0         04
# 1         04
# 2         04
# 3         04
# 4         04
#           ..
# 115375     u
# 115376     u
# 115377     u
# 115378     u
# 115379     u
# Name: variable, Length: 115380, dtype: object

# %%
tb_data_processed
# Out:
#        iso2  year variable  value
# 0        AD  1989      m04    NaN
# 1        AD  1990      m04    NaN
# 2        AD  1991      m04    NaN
# 3        AD  1992      m04    NaN
# 4        AD  1993      m04    NaN
# ...     ...   ...      ...    ...
# 115375   ZW  2004       fu    NaN
# 115376   ZW  2005       fu    NaN
# 115377   ZW  2006       fu    NaN
# 115378   ZW  2007       fu    NaN
# 115379   ZW  2008       fu    0.0
#
# [115380 rows x 4 columns]

# %%
tb = tb_data

# %%
def process_age_group(age_group):
    ages = {"04": "0-4", "65": "65+", "u": "unknown"}
    if age_group in ages:
        return ages[age_group]
    else:
        # Put a dash before the last two digits
        return f"{age_group[:-2]}-{age_group[-2:]}"
tb = tb.melt(
 id_vars = ["iso2", "year"], var_name = "sex_and_age", value_name = "cases")
tb["sex"] = tb.sex_and_age.str.get(0)
tb["age_group"] = tb.sex_and_age.str.slice(1)
tb = tb.drop(columns = "sex_and_age")
tb.age_group = tb.age_group.apply(process_age_group)
# Tidy up the column and row order
tb = tb[["iso2", "year", "sex", "age_group", "cases"]]
tb = tb.sort_values(["iso2", "year"])

# %%
tb
# Out:
#        iso2  year sex age_group  cases
# 0        AD  1989   m       0-4    NaN
# 5769     AD  1989   m      5-14    NaN
# 11538    AD  1989   m      0-14    NaN
# 17307    AD  1989   m     15-24    NaN
# 23076    AD  1989   m     25-34    NaN
# ...     ...   ...  ..       ...    ...
# 90248   NaN  2008   f     35-44  437.0
# 96017   NaN  2008   f     45-54  226.0
# 101786  NaN  2008   f     55-64  110.0
# 107555  NaN  2008   f       65+   80.0
# 113324  NaN  2008   f   unknown    0.0
#
# [115380 rows x 5 columns]

# %%
tb_data.year
# Out:
# 0       1989
# 1       1990
# 2       1991
# 3       1992
# 4       1993
#         ...
# 5764    2004
# 5765    2005
# 5766    2006
# 5767    2007
# 5768    2008
# Name: year, Length: 5769, dtype: int64

# %%
tb_data.year.apply(lambda y: 1980 if y < 1990 else 1990)
# Out:
# 0       1980
# 1       1990
# 2       1990
# 3       1990
# 4       1990
#         ...
# 5764    1990
# 5765    1990
# 5766    1990
# 5767    1990
# 5768    1990
# Name: year, Length: 5769, dtype: int64
