# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Homework 1
# ## Data Tidying and Cleaning

# %%
# Reading the dataset... Naming it coffee_data
## The "../" helps referring to the parent folder of the current one.
coffee_data = pd.read_csv("../data/merged_data_cleaned.csv")

# %%
coffee_data
# Out:
#       Unnamed: 0  Species                     Owner Country.of.Origin  \
# 0              0  Arabica                 metad plc          Ethiopia
# 1              1  Arabica                 metad plc          Ethiopia
# 2              2  Arabica  grounds for health admin         Guatemala
# 3              3  Arabica       yidnekachew dabessa          Ethiopia
# 4              4  Arabica                 metad plc          Ethiopia
# ...          ...      ...                       ...               ...
# 1334        1334  Robusta               luis robles           Ecuador
# 1335        1335  Robusta               luis robles           Ecuador
# 1336        1336  Robusta               james moore     United States
# 1337        1337  Robusta             cafe politico             India
# 1338        1338  Robusta             cafe politico           Vietnam
#
#                                      Farm.Name Lot.Number            Mill  \
# 0                                    metad plc        NaN       metad plc
# 1                                    metad plc        NaN       metad plc
# 2     san marcos barrancas "san cristobal cuch        NaN             NaN
# 3        yidnekachew dabessa coffee plantation        NaN         wolensu
# 4                                    metad plc        NaN       metad plc
# ...                                        ...        ...             ...
# 1334                                 robustasa   Lavado 1     our own lab
# 1335                                 robustasa   Lavado 3  own laboratory
# 1336                           fazenda cazengo        NaN    cafe cazengo
# 1337                                       NaN        NaN             NaN
# 1338                                       NaN        NaN             NaN
#
#              ICO.Number                                Company       Altitude  \
# 0             2014/2015      metad agricultural developmet plc      1950-2200
# 1             2014/2015      metad agricultural developmet plc      1950-2200
# 2                   NaN                                    NaN  1600 - 1800 m
# 3                   NaN  yidnekachew debessa coffee plantation      1800-2200
# 4             2014/2015      metad agricultural developmet plc      1950-2200
# ...                 ...                                    ...            ...
# 1334                NaN                              robustasa            NaN
# 1335                NaN                              robustasa             40
# 1336                NaN                global opportunity fund     795 meters
# 1337  14-1118-2014-0087                          cafe politico            NaN
# 1338                NaN                          cafe politico            NaN
#
#       ...       Color Category.Two.Defects           Expiration  \
# 0     ...       Green                    0      April 3rd, 2016
# 1     ...       Green                    1      April 3rd, 2016
# 2     ...         NaN                    0       May 31st, 2011
# 3     ...       Green                    2     March 25th, 2016
# 4     ...       Green                    2      April 3rd, 2016
# ...   ...         ...                  ...                  ...
# 1334  ...  Blue-Green                    1   January 18th, 2017
# 1335  ...  Blue-Green                    0   January 18th, 2017
# 1336  ...         NaN                    6  December 23rd, 2015
# 1337  ...       Green                    1    August 25th, 2015
# 1338  ...         NaN                    9    August 25th, 2015
#
#                       Certification.Body  \
# 0     METAD Agricultural Development plc
# 1     METAD Agricultural Development plc
# 2           Specialty Coffee Association
# 3     METAD Agricultural Development plc
# 4     METAD Agricultural Development plc
# ...                                  ...
# 1334        Specialty Coffee Association
# 1335        Specialty Coffee Association
# 1336        Specialty Coffee Association
# 1337        Specialty Coffee Association
# 1338        Specialty Coffee Association
#
#                          Certification.Address  \
# 0     309fcf77415a3661ae83e027f7e5f05dad786e44
# 1     309fcf77415a3661ae83e027f7e5f05dad786e44
# 2     36d0d00a3724338ba7937c52a378d085f2172daa
# 3     309fcf77415a3661ae83e027f7e5f05dad786e44
# 4     309fcf77415a3661ae83e027f7e5f05dad786e44
# ...                                        ...
# 1334  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1335  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1336  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1337  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1338  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
#
#                          Certification.Contact unit_of_measurement  \
# 0     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 1     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 2     0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 3     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 4     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# ...                                        ...                 ...
# 1334  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1335  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1336  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1337  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1338  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
#
#      altitude_low_meters altitude_high_meters altitude_mean_meters
# 0                 1950.0               2200.0               2075.0
# 1                 1950.0               2200.0               2075.0
# 2                 1600.0               1800.0               1700.0
# 3                 1800.0               2200.0               2000.0
# 4                 1950.0               2200.0               2075.0
# ...                  ...                  ...                  ...
# 1334                 NaN                  NaN                  NaN
# 1335                40.0                 40.0                 40.0
# 1336               795.0                795.0                795.0
# 1337                 NaN                  NaN                  NaN
# 1338                 NaN                  NaN                  NaN
#
# [1339 rows x 44 columns]

# %%
# Size of the dataset
coffee_data.shape
# Out:
# (1339, 44)

# %%
# Columns (variables / features) in the dataset
coffee_data.columns
# Out:
# Index(['Unnamed: 0', 'Species', 'Owner', 'Country.of.Origin', 'Farm.Name',
#        'Lot.Number', 'Mill', 'ICO.Number', 'Company', 'Altitude', 'Region',
#        'Producer', 'Number.of.Bags', 'Bag.Weight', 'In.Country.Partner',
#        'Harvest.Year', 'Grading.Date', 'Owner.1', 'Variety',
#        'Processing.Method', 'Aroma', 'Flavor', 'Aftertaste', 'Acidity', 'Body',
#        'Balance', 'Uniformity', 'Clean.Cup', 'Sweetness', 'Cupper.Points',
#        'Total.Cup.Points', 'Moisture', 'Category.One.Defects', 'Quakers',
#        'Color', 'Category.Two.Defects', 'Expiration', 'Certification.Body',
#        'Certification.Address', 'Certification.Contact', 'unit_of_measurement',
#        'altitude_low_meters', 'altitude_high_meters', 'altitude_mean_meters'],
#       dtype='object')

# %%
# Types of variables
coffee_data.dtypes
# Out:
# Unnamed: 0                 int64
# Species                   object
# Owner                     object
# Country.of.Origin         object
# Farm.Name                 object
# Lot.Number                object
# Mill                      object
# ICO.Number                object
# Company                   object
# Altitude                  object
# Region                    object
# Producer                  object
# Number.of.Bags             int64
# Bag.Weight                object
# In.Country.Partner        object
# Harvest.Year              object
# Grading.Date              object
# Owner.1                   object
# Variety                   object
# Processing.Method         object
# Aroma                    float64
# Flavor                   float64
# Aftertaste               float64
# Acidity                  float64
# Body                     float64
# Balance                  float64
# Uniformity               float64
# Clean.Cup                float64
# Sweetness                float64
# Cupper.Points            float64
# Total.Cup.Points         float64
# Moisture                 float64
# Category.One.Defects       int64
# Quakers                  float64
# Color                     object
# Category.Two.Defects       int64
# Expiration                object
# Certification.Body        object
# Certification.Address     object
# Certification.Contact     object
# unit_of_measurement       object
# altitude_low_meters      float64
# altitude_high_meters     float64
# altitude_mean_meters     float64
# dtype: object

# %%
# Checking if the column "Unnamed: 0" is the same as the "index" column
coffee_data["Unnamed: 0"].nunique()
# Out:
# 1339

# %%
# Remove the unnecessary column ["Unnamed: 0"] as it is the same as the index 
# (proven by the previous row - we have 1339 unique values which is exactly the role of the index)
coffee_data = coffee_data.drop(columns = "Unnamed: 0")

# %%
coffee_data.columns
# Out:
# Index(['Species', 'Owner', 'Country.of.Origin', 'Farm.Name', 'Lot.Number',
#        'Mill', 'ICO.Number', 'Company', 'Altitude', 'Region', 'Producer',
#        'Number.of.Bags', 'Bag.Weight', 'In.Country.Partner', 'Harvest.Year',
#        'Grading.Date', 'Owner.1', 'Variety', 'Processing.Method', 'Aroma',
#        'Flavor', 'Aftertaste', 'Acidity', 'Body', 'Balance', 'Uniformity',
#        'Clean.Cup', 'Sweetness', 'Cupper.Points', 'Total.Cup.Points',
#        'Moisture', 'Category.One.Defects', 'Quakers', 'Color',
#        'Category.Two.Defects', 'Expiration', 'Certification.Body',
#        'Certification.Address', 'Certification.Contact', 'unit_of_measurement',
#        'altitude_low_meters', 'altitude_high_meters', 'altitude_mean_meters'],
#       dtype='object')

# %%
# See if Species can be turned into a categorical variable instead of being an object var
coffee_data.Species
# Out:
# 0       Arabica
# 1       Arabica
# 2       Arabica
# 3       Arabica
# 4       Arabica
#          ...
# 1334    Robusta
# 1335    Robusta
# 1336    Robusta
# 1337    Robusta
# 1338    Robusta
# Name: Species, Length: 1339, dtype: object

# %%
coffee_data.Species.value_counts(dropna = False)
# Out:
# Species
# Arabica    1311
# Robusta      28
# Name: count, dtype: int64

# %%
# As there are only two types of coffee species, the feature "species" can be turned into a categorical variable
coffee_data.Species = coffee_data.Species.astype("category")

# %%
coffee_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1339 entries, 0 to 1338
# Data columns (total 43 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Species                1339 non-null   category
#  1   Owner                  1332 non-null   object
#  2   Country.of.Origin      1338 non-null   object
#  3   Farm.Name              980 non-null    object
#  4   Lot.Number             276 non-null    object
#  5   Mill                   1021 non-null   object
#  6   ICO.Number             1180 non-null   object
#  7   Company                1130 non-null   object
#  8   Altitude               1113 non-null   object
#  9   Region                 1280 non-null   object
#  10  Producer               1107 non-null   object
#  11  Number.of.Bags         1339 non-null   int64
#  12  Bag.Weight             1339 non-null   object
#  13  In.Country.Partner     1339 non-null   object
#  14  Harvest.Year           1292 non-null   object
#  15  Grading.Date           1339 non-null   object
#  16  Owner.1                1332 non-null   object
#  17  Variety                1113 non-null   object
#  18  Processing.Method      1169 non-null   object
#  19  Aroma                  1339 non-null   float64
#  20  Flavor                 1339 non-null   float64
#  21  Aftertaste             1339 non-null   float64
#  22  Acidity                1339 non-null   float64
#  23  Body                   1339 non-null   float64
#  24  Balance                1339 non-null   float64
#  25  Uniformity             1339 non-null   float64
#  26  Clean.Cup              1339 non-null   float64
#  27  Sweetness              1339 non-null   float64
#  28  Cupper.Points          1339 non-null   float64
#  29  Total.Cup.Points       1339 non-null   float64
#  30  Moisture               1339 non-null   float64
#  31  Category.One.Defects   1339 non-null   int64
#  32  Quakers                1338 non-null   float64
#  33  Color                  1069 non-null   object
#  34  Category.Two.Defects   1339 non-null   int64
#  35  Expiration             1339 non-null   object
#  36  Certification.Body     1339 non-null   object
#  37  Certification.Address  1339 non-null   object
#  38  Certification.Contact  1339 non-null   object
#  39  unit_of_measurement    1339 non-null   object
#  40  altitude_low_meters    1109 non-null   float64
#  41  altitude_high_meters   1109 non-null   float64
#  42  altitude_mean_meters   1109 non-null   float64
# dtypes: category(1), float64(16), int64(3), object(23)
# memory usage: 440.9+ KB

# %%
# Make the columns in a more pythonic style
coffee_data.columns = coffee_data.columns.str.lower()

# %%
coffee_data = coffee_data.rename(columns = lambda col: col.replace(".", "_"))

# %%
coffee_data.species.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1339 entries, 0 to 1338
# Series name: species
# Non-Null Count  Dtype
# --------------  -----
# 1339 non-null   category
# dtypes: category(1)
# memory usage: 1.6 KB

# %%
coffee_data.columns
# Out:
# Index(['species', 'owner', 'country_of_origin', 'farm_name', 'lot_number',
#        'mill', 'ico_number', 'company', 'altitude', 'region', 'producer',
#        'number_of_bags', 'bag_weight', 'in_country_partner', 'harvest_year',
#        'grading_date', 'owner_1', 'variety', 'processing_method', 'aroma',
#        'flavor', 'aftertaste', 'acidity', 'body', 'balance', 'uniformity',
#        'clean_cup', 'sweetness', 'cupper_points', 'total_cup_points',
#        'moisture', 'category_one_defects', 'quakers', 'color',
#        'category_two_defects', 'expiration', 'certification_body',
#        'certification_address', 'certification_contact', 'unit_of_measurement',
#        'altitude_low_meters', 'altitude_high_meters', 'altitude_mean_meters'],
#       dtype='object')

# %%
coffee_data.owner
# Out:
# 0                      metad plc
# 1                      metad plc
# 2       grounds for health admin
# 3            yidnekachew dabessa
# 4                      metad plc
#                   ...
# 1334                 luis robles
# 1335                 luis robles
# 1336                 james moore
# 1337               cafe politico
# 1338               cafe politico
# Name: owner, Length: 1339, dtype: object

# %%
# View the owners and how many times they appear in the dataset
coffee_data.owner.value_counts(dropna = False)
# Out:
# owner
# juan luis alvarado romero            155
# racafe & cia s.c.a                    60
# exportadora de cafe condor s.a        54
# kona pacific farmers cooperative      52
# ipanema coffees                       50
#                                     ...
# kasozi coffee farmers association      1
# nitubaasa ltd                          1
# mannya coffee project                  1
# yidnekachew dabessa                    1
# james moore                            1
# Name: count, Length: 316, dtype: int64

# %%
# It is better to upper their names
coffee_data.owner = coffee_data.owner.str.upper()

# %%
coffee_data.owner

coffee_data.owner.unique()
# Out:
# array(['METAD PLC', 'GROUNDS FOR HEALTH ADMIN', 'YIDNEKACHEW DABESSA',
#        'JI-AE AHN', 'HUGO VALDIVIA', 'ETHIOPIA COMMODITY EXCHANGE',
#        'DIAMOND ENTERPRISE PLC', 'MOHAMMED LALO',
#        'CQI Q COFFEE SAMPLE REPRESENTATIVE', 'YUNNAN COFFEE EXCHANGE',
#        'ESSENCECOFFEE', 'THE COFFEE SOURCE INC.', 'ROBERTO LICONA FRANCO',
#        'NUCOFFEE', 'KABUM TRADING COMPANY', 'BISMARCK CASTRO',
#        'LIN, CHE-HAO KRUDE 林哲豪', 'NORA ZEAS', 'SPECIALTY COFFEE-KOREA',
#        'FRANCISCO A MENA', 'HIDER ABAMECHA', 'DANIEL MAGU',
#        'KONA PACIFIC FARMERS COOPERATIVE', 'ITDP INTERNATIONAL',
#        'JACQUES PEREIRA CARNEIRO', 'JUNGLE ESTATE',
#        'GREAT LAKES COFFEE UGANDA', 'LUSSO LAB', 'AFCA',
#        'JUAN LUIS ALVARADO ROMERO', 'KAWACOM UGANDA LTD',
#        'EXPORTADORA DE CAFE CONDOR S.A', 'GONZALO HERNANDEZ',
#        'IBRAHIM HUSSIEN SPECIALITY COFFEE PRODUCER &EXPORT',
#        'SEID DAMTEW COFFEE PLANATAION', 'DANE LORAAS',
#        'COLBRAN COFFEELANDS, LTD.', 'ATLANTIC SPECIALTY COFFEE',
#        'ASSEFA BELAY COFFEE PRODUCER', 'KYAGALANYI LTD',
#        'RASHID MOLEDINA & CO. (MSA) LTD.', 'IBERO KENYA LIMITED',
#        'COMPAÑIA COLOMBIANA AGROINDUSTRIAL S.A',
#        'NOMURA TRADING CO., LTD.', 'CARCAFE LTDA CI', 'STEVEN KIL',
#        'EILEEN KOYANAGI', 'KYAGALANYI COFFEE LTD', 'RACAFE & CIA S.C.A',
#        'TROY QUIMBY', 'EL EQUIMITE, CAFETAL BIODINÁMICO', 'SIMON MAHINDA',
#        'YOUNG KIM', 'CARL WALKER', 'TAYLOR WINCH (T) LTD',
#        'ARTEMIO ZAPATA TEJEDA', 'BRIAN SPECKMAN', 'PHILIP SCHLUTER',
#        '松澤宏樹 KOJU MATSUZAWA', 'LYDIAH MWANGI', 'CADEXSA',
#        'CONSEJO SALVADOREÑO DEL CAFÉ', 'SANJAVA COFFEE', 'RODRIGO SOTO',
#        'FABIAN CALDERON MORA', 'ERIC THORMAEHLEN', 'ROB TUTTLE',
#        'CQI TAIWAN ICP CQI台灣合作夥伴', 'DREAM TOGETHER',
#        'ORGANIZACIONES DE PRODUCTORES DE CAFE COLIMENSE',
#        'BENJAMIN SCHMERLER', 'TAYLOR WINCH (COFFEE) LTD.', 'MAX GURDIAN',
#        'ECOM JAPAN LIMITED', 'FEDERACION NACIONAL DE CAFETEROS',
#        'ERIC WU', 'MARIA IMELDA USCANGA MARTINEZ', 'ALFREDO BOJALIL',
#        'DANIEL FRIEDLANDER', 'ALEXANDRA KATONA-CARROLL',
#        'AULIA ARIF SYAHRI', 'KAO MING LEE',
#        'MARIA AMALIA GUADALUPE TORIELLO ELORZA', 'RAÚL VARGAS',
#        'VICTOR HUGO MELCHOR CORDOVA', 'TEMBO COFFEE COMPANY LTD',
#        'JESUS SALAZAR VELASCO', 'MANUEL HERRERA JUAREZ', 'WAYNER JIMENEZ',
#        'COOPERATIVA EL GORRION R.L', 'CAFEBRAS', 'CECA, S.A.',
#        'ASEFA DUKAMO KEROMA', 'SELIAN COFFEE ESTATE',
#        'OLAM AGRO COLOMBIA', 'CHRIS FINCH', 'ITOCHU CORPORATION',
#        'OWEN CARVER', 'PT.ROYAL PACIFIC INDAH INTERNATIONAL',
#        'ANDRES MARTINEZ LEON', 'AMANDA POWERS', 'IPANEMA COFFEES',
#        'DOI TUNG DEVELOPMENT PROJECT', 'CAFES TOMARI SA DE CV',
#        'SARAWUT PREMJIT', 'ALMACAFE', 'OSCAR ORTEGA CARBALLO',
#        'YASMIN COFFFEE PLANTATION PLC', 'GARET ALBAN',
#        'FILEMON MENDOZA CAMPOS', 'DOI CHAANG COFFEE COMPANY',
#        'KENNEDY MACHARIA', 'NILE HIGHLAND ARABICA COFFEE FARMERS',
#        'GERMAN NEGRON', 'SAUL M. HERNANDEZ RAMIREZ',
#        'COMERCIAL INTERNACIONAL EXPORTADORA, S.A.', 'ROB STEPHEN',
#        'JUAN LUIS ORTEGA CARBALLO', 'EKAI INTERNATIONAL COMPANY LTD.',
#        'ANDREAS KUSSMAUL', 'BULAMBURI COFFEE FARMERS ASSOCIATION',
#        'DAMARI ABSALOME', 'DEBESA AGRO INDUSTRY PLC', nan,
#        'MIGUEL CORTES MORENO', 'GABRIEL BERNARDO RIVAS ROSS',
#        'FELIPE ISAZA', 'SPECIALTY COFFEE ASSOCIATION OF INDONESIA',
#        'BUGISU COOPERATIVE UNION', 'BOURBON SPECIALTY COFFEES',
#        'NGILA ESTATE LTD', 'J.ANDRADE', 'ITIAH COFFEE LLC',
#        'CAFE DE DON BALBINO S.C. DE R.L. DE C.V.',
#        'PRODUCTOS Y SERVICIOS CHILINDRON S.A. DE C.V.',
#        'CALIXTO GUILLEN VAZQUEZ', 'ERNESTO RODRIGUEZ LUNA',
#        'MODESTO LANDEROS FLORES', 'ANDREA BERNAL', 'SUNVIRTUE CO., LTD.',
#        'TUTUNZE KAHAWA LTD', 'CAFE POLITICO', 'MAYRA YESSENIA TORRES',
#        'BALAM HINYULA', 'NESTOR MENDEZ GOMEZ',
#        'FERNANDO MENDOZA APARICIO',
#        'MARIA LUISA DEL CARMEN ROJAS NARVAEZ', 'UCFA',
#        'IRENE ALVES SANTOS', 'STAR CAFE LTD',
#        'ROSA AURORA FALCON FERNANDEZ', 'SANTIAGO SOLIS AYERDI',
#        'RENEE A. PERRINE', 'ZARAH ZAMORA PEREZ', 'ANDREW BOWMAN',
#        'EXPOCACCER COOP DOS CAFEIC DO CERRADO LTDA',
#        'NYAPEA COFFEE FARMERS ASSOCIATION', 'MARIA GUADALUPE GOMEZ ANZO',
#        'ROYAL BASE CORPORATION', 'VERONICA LOPEZ CASTILLEJOS',
#        'SAMUEL MUHIRWA', 'JOSHUA MARSCEAU', 'COFFEEBYTHEBAG.COM , INC',
#        'EDWIN AGASSO', 'ARMANDO LUIS POHLENZ MARTINEZ', 'COFFEE EXPORT',
#        'SERGIO DE LA VEQUIA BERNARDI', 'ROMULO BELLO FLORES',
#        'RACHEL PETERSON', 'JOSÉ LUIS ROJAS YEO', 'NITIN COFFEE ESTATE',
#        'ADAM KLINE', 'MONTEGRANDE',
#        'GRUPO CAFETALERO LOS BRUJOS SPR DE RL', 'GEORGE A. FERNANDEZ',
#        'GABRIEL BARBARA', 'ANDRY SIMARMATA', 'BRENT HALL',
#        'GUILLERMO ROJAS SALDANA', 'ELSY REYES', 'SHAH PLANTATIONS',
#        'AMKENI GOURMET COFFEE GROUP', 'ENRIQUE MITRE LOPEZ',
#        'ENRIQUE EDUARDO LOPEZ AGUILAR', 'BRIAN BECK',
#        'GLADNESS OBED PALLANGYO', 'DARIO CESAR GALEANA SANCHEZ',
#        'JOSE DANIEL COBILT CASTRO', 'ALVARO QUIROS PEREZ',
#        'OLIVIA HERNANDEZ VIRVES', 'FINCA LAS NIEVES',
#        'PEDRO SANTOS E SILVA', 'MICHAEL GAVINA', 'KLEM ORGANICS',
#        'JESUS CARLOS CARDENAS VALDIVIA', 'BENCAFE, S. A.',
#        'LANGIRO FARM GROUP', 'IBERO COFFEE TRADING CO (T) LTD',
#        'SALVADOR CARO CARRION', 'CAFETALERA INTERNACIONAL CAFINTER, S.A.',
#        'NGOROGORO CONVENANT ESTATE', 'JULIO PEREZ HERNANDEZ', 'DIDAS',
#        'MINWOOK KU', 'FINCA ESTATE', 'BENEFICIO SANTA ROSA',
#        'JORGE OCTAVIO ESCAMILLA PRADO', 'MCOMAFA CO LTD',
#        'JUAN HERMILIO SAMPIERI CARCAMO', 'U MG MG', 'VIRIDIANA',
#        'KURT KAPPELI', 'CHRISTINA DUSING',
#        'JORGE FRANCISCO MARTINEZ HACHITY', 'SERGIO LANDA ALARCON',
#        'DIEGO MANUEL WOOLRICH RAMIREZ', 'DAE LTD COMPANY',
#        'FREDY GORDILLO REYES', 'VIRGINIA GORDILLO GORDILLO',
#        'JOSE LUIS MUNOZ GUERRERO', 'MDH', 'ACACIA HILLS LTD',
#        'EXPORTADORA ATLANTIC, S.A.', 'GENIUS COFFEE',
#        'SANTA LAURA EXPORTADORA DE CAFE S.L.E.C. S.A.',
#        'MYRIAM KAPLAN-PASTERNAK', 'TOMAS EDELMANN BLASS',
#        'MARIA DE LA PAZ AGUILAR GUILLEN', 'ANGEL OSCAR MEDINA RODRIGUEZ',
#        'VICTORIA', 'HECTOR GABRIEL BARREDA NADER',
#        'SHANGRILLA ESTATE LTD', 'IMMACULATA JOHN', 'KERCHANSHE',
#        'GREGORIO SEBBA', 'ROLANDO LACAYO', 'WALI ALI',
#        'OBED RENDON PONCE', 'GERARDO HERNANDEZ VALDERRABANO',
#        'BALBINO RAMIREZ FLORES', 'MLIMANI NGARASHI',
#        'ALEJANDRO GARCIA PALACIOS', 'GRUPO SANTAB S.A DE C.V.',
#        'MIN HLAING', 'KARATU ESTATE',
#        'EDUARDO LUIS AUGUSTO VELAZQUEZ SOLIS',
#        'LUIS ROBERTO FERMOSO BELTRAN', 'JOSE MANUEL VERGARA CORTES',
#        'U SOE', 'BURKA COFFEE ESTATE', 'JANNY MARLITH TORRES',
#        'CASE NOYALE LTD', 'SHWE YIN MAR COFFEE',
#        'ISRAEL EDUARDO PAZ GARCIA', 'ADAM CIRULI YE',
#        'DELFINA LEON SHINE', 'KONGONI ESTATE', 'VOLCAFE LTDA. - BRASIL',
#        'BOB MCCAULEY', 'U HTUN HTUN', 'GLORIA ANTONIETA ESCOBAR URRUTIA',
#        'HONOR DELA FUENTE', 'PABLO ENRIQUE MARTINEZ GAMA',
#        'MARCO VIRGILIO RAMIREZ TELIZ', 'BRAYAN CUNHA SOUZA',
#        'FEDERICO PACHECO PEREZ', 'NGU SHWE LI',
#        'SEMIRAMIS CASAS VELAZQUEZ', 'JESUS CARLOS CADENA VALDIVIA',
#        'ASOCIACIÓN ALDEA GLOBAL JINOTEGA', 'LEONIDES DE LA CRUZ LOPEZ',
#        'MARIO JOSE FERNANDEZ', 'ADRIANA TORRES RICO QUEVEDO',
#        'RRE KUNENE', 'ERIC JESUS CORDOBA ARROYO',
#        'JULIO CESAR ROBLES FLORES', 'MASAMICHI HIROIKE',
#        'JUANA RODRIGUEZ GUTIERREZ',
#        'CAFES FINOS DE EXPORTACION S DE R.L.',
#        'SUSTAINABLE HARVEST COFFEE', 'GONZALO DE AQUINO FLORES',
#        'JUAN AVENAMAR RODRIGUEZ FUNEZ', 'OCTAVIO AUGUSTO DIAZ TREJO',
#        'DAMASO MARTINEZ PEREZ',
#        'PRODUCTORES DE ESPECIALIDAD EMILIANO ZAPEATA, SPR.',
#        'JUAN GARCIA HERNANDEZ', 'ROSARIO MIGUEL HERNANDEZ',
#        'FRANCISCO RUIZ NUNEZ', 'PABLO CERVANTES MORELOS        ',
#        'GUSTAVO AMIEVA GONZALEZ', 'SAMUEL ELI GUREL', 'MAO-HENG CHU',
#        'GUSTAVO ABARCA SOLIS', 'STEPHANY ESCAMILLA FEMAT',
#        'HOMERO ANTONIO DE ANDA ANDRADE', 'WILLIAM HO',
#        'GUILLERMO EDUARDO BOBADILLA MUGUIRA', 'ANA GONZALES',
#        'FRANCISCO HERNANDEZ LORENZO', 'MARTIN JIMENEZ CASIANO',
#        'GRUPO JUVENIL MAGTAYANI, AC', 'MYRNA ROXANA GALVEZ GONZALEZ',
#        'EUGENE HOLMAN PEW', 'JOSE ARMANDO NORBERTO BORZANI LEMINI',
#        'RICARDO AARON SAMPIERI MARINI', 'JUAN CARLOS GARCIA LOPEZ',
#        'ANKOLE COFFEE PRODUCERS COOP', 'NISHANT GURJER', 'ANDREW HETZEL',
#        'UGACOF', 'KATUKA DEVELOPMENT TRUST LTD',
#        'KASOZI COFFEE FARMERS ASSOCIATION', 'NITUBAASA LTD',
#        'MANNYA COFFEE PROJECT', 'LUIS ROBLES', 'JAMES MOORE'],
#       dtype=object)

# %%
# These are the records that do not have an owner but I spot something else here.
## A lot of records have a duplicate but with some little differences which come from the ico_number
coffee_data[coffee_data.owner.isna() == True]
# Out:
#       species owner country_of_origin                   farm_name lot_number  \
# 364   Arabica   NaN          Honduras                los hicaques        NaN
# 459   Arabica   NaN          Honduras                los hicaques        NaN
# 602   Arabica   NaN          Colombia  supply chain ecom cca s.a.        NaN
# 848   Arabica   NaN          Honduras  gran manzana y el aguacate        NaN
# 882   Arabica   NaN          Honduras  gran manzana y el aguacate        NaN
# 975   Arabica   NaN          Honduras                los hicaques        NaN
# 1044  Arabica   NaN          Honduras                los hicaques        NaN
#
#              mill  ico_number        company        altitude          region  \
# 364    cigrah sps  13-111-240         cigrah            1350       comayagua
# 459    cigrah sps  13-111-193         cigrah            1350       comayagua
# 602   south huila   3-79-0334  ecom cca s.a.  1400 thru 1850     south huila
# 848    cigrah sps  13-111-311         cigrah            1350       comayagua
# 882    cigrah sps  13-111-192         cigrah            1400       comayagua
# 975        cigrah  13-111-037         cigrah       1450 mals  central region
# 1044       cigrah  13-111-035         cigrah       1450 mals  central region
#
#       ...       color  category_two_defects        expiration  \
# 364   ...       Green                     3   April 8th, 2015
# 459   ...       Green                     3   April 8th, 2015
# 602   ...  Blue-Green                     0  April 11th, 2013
# 848   ...       Green                     4    May 16th, 2015
# 882   ...       Green                     5    May 16th, 2015
# 975   ...       Green                     1  March 10th, 2016
# 1044  ...       Green                     1  March 10th, 2016
#
#                 certification_body                     certification_address  \
# 364   Instituto Hondureño del Café  b4660a57e9f8cc613ae5b8f02bfce8634c763ab4
# 459   Instituto Hondureño del Café  b4660a57e9f8cc613ae5b8f02bfce8634c763ab4
# 602                       Almacafé  e493c36c2d076bf273064f7ac23ad562af257a25
# 848   Instituto Hondureño del Café  b4660a57e9f8cc613ae5b8f02bfce8634c763ab4
# 882   Instituto Hondureño del Café  b4660a57e9f8cc613ae5b8f02bfce8634c763ab4
# 975   Instituto Hondureño del Café  b4660a57e9f8cc613ae5b8f02bfce8634c763ab4
# 1044  Instituto Hondureño del Café  b4660a57e9f8cc613ae5b8f02bfce8634c763ab4
#
#                          certification_contact unit_of_measurement  \
# 364   7f521ca403540f81ec99daec7da19c2788393880                   m
# 459   7f521ca403540f81ec99daec7da19c2788393880                   m
# 602   70d3c0c26f89e00fdae6fb39ff54f0d2eb1c38ab                   m
# 848   7f521ca403540f81ec99daec7da19c2788393880                   m
# 882   7f521ca403540f81ec99daec7da19c2788393880                   m
# 975   7f521ca403540f81ec99daec7da19c2788393880                   m
# 1044  7f521ca403540f81ec99daec7da19c2788393880                   m
#
#      altitude_low_meters altitude_high_meters  altitude_mean_meters
# 364               1350.0               1350.0                1350.0
# 459               1350.0               1350.0                1350.0
# 602               1400.0               1850.0                1625.0
# 848               1350.0               1350.0                1350.0
# 882               1400.0               1400.0                1400.0
# 975               1450.0               1450.0                1450.0
# 1044              1450.0               1450.0                1450.0
#
# [7 rows x 43 columns]

# %%
coffee_data[["owner", "farm_name"]].sample(20)
# Out:
#                                        owner  \
# 667                      ENRIQUE MITRE LOPEZ
# 347                       RACAFE & CIA S.C.A
# 294              ETHIOPIA COMMODITY EXCHANGE
# 150   COMPAÑIA COLOMBIANA AGROINDUSTRIAL S.A
# 607                          IPANEMA COFFEES
# 35                               DANIEL MAGU
# 99          EL EQUIMITE, CAFETAL BIODINÁMICO
# 546                JUAN LUIS ALVARADO ROMERO
# 1323                           ANDREW HETZEL
# 514           EXPORTADORA DE CAFE CONDOR S.A
# 497                          IPANEMA COFFEES
# 752           EXPORTADORA DE CAFE CONDOR S.A
# 710                             RODRIGO SOTO
# 87                    THE COFFEE SOURCE INC.
# 961                            KLEM ORGANICS
# 281            YASMIN COFFFEE PLANTATION PLC
# 904                     FREDY GORDILLO REYES
# 340                         ANDREAS KUSSMAUL
# 479                       RACAFE & CIA S.C.A
# 1073                     SHWE YIN MAR COFFEE
#
#                                      farm_name
# 667                                 caltuchoco
# 347                                        NaN
# 294   phone number | 0911-51-08-01, email | at
# 150                                        NaN
# 607                                capoeirinha
# 35                                     kangunu
# 99                                     various
# 546                               finca medina
# 1323                        sethuraman estates
# 514                                        NaN
# 497                         fazenda capoeirnha
# 752                                        NaN
# 710                                  rio jorco
# 87             coop. hoja blanca - fedecocagua
# 961                         fazendas klem ltda
# 281                                        NaN
# 904                     union ramal santa cruz
# 340                exportadora café california
# 479                                        NaN
# 1073                                     mixed

# %%
# As I do not known the owner, I think that the best option is to replace the NaN values with "Unknown".
# According to my research, some coffee brands do not have an exact owner such as the coffee from Honduras - 
# actually there is no farm Ios Hicaques because that is a coffee-producing region in Honduras
coffee_data.owner = coffee_data.owner.fillna("Unknown")

# %%
coffee_data[coffee_data.owner == "Unknown"]
# Out:
#       species    owner country_of_origin                   farm_name  \
# 364   Arabica  Unknown          Honduras                los hicaques
# 459   Arabica  Unknown          Honduras                los hicaques
# 602   Arabica  Unknown          Colombia  supply chain ecom cca s.a.
# 848   Arabica  Unknown          Honduras  gran manzana y el aguacate
# 882   Arabica  Unknown          Honduras  gran manzana y el aguacate
# 975   Arabica  Unknown          Honduras                los hicaques
# 1044  Arabica  Unknown          Honduras                los hicaques
#
#      lot_number         mill  ico_number        company        altitude  \
# 364         NaN   cigrah sps  13-111-240         cigrah            1350
# 459         NaN   cigrah sps  13-111-193         cigrah            1350
# 602         NaN  south huila   3-79-0334  ecom cca s.a.  1400 thru 1850
# 848         NaN   cigrah sps  13-111-311         cigrah            1350
# 882         NaN   cigrah sps  13-111-192         cigrah            1400
# 975         NaN       cigrah  13-111-037         cigrah       1450 mals
# 1044        NaN       cigrah  13-111-035         cigrah       1450 mals
#
#               region  ...       color  category_two_defects        expiration  \
# 364        comayagua  ...       Green                     3   April 8th, 2015
# 459        comayagua  ...       Green                     3   April 8th, 2015
# 602      south huila  ...  Blue-Green                     0  April 11th, 2013
# 848        comayagua  ...       Green                     4    May 16th, 2015
# 882        comayagua  ...       Green                     5    May 16th, 2015
# 975   central region  ...       Green                     1  March 10th, 2016
# 1044  central region  ...       Green                     1  March 10th, 2016
#
#                 certification_body                     certification_address  \
# 364   Instituto Hondureño del Café  b4660a57e9f8cc613ae5b8f02bfce8634c763ab4
# 459   Instituto Hondureño del Café  b4660a57e9f8cc613ae5b8f02bfce8634c763ab4
# 602                       Almacafé  e493c36c2d076bf273064f7ac23ad562af257a25
# 848   Instituto Hondureño del Café  b4660a57e9f8cc613ae5b8f02bfce8634c763ab4
# 882   Instituto Hondureño del Café  b4660a57e9f8cc613ae5b8f02bfce8634c763ab4
# 975   Instituto Hondureño del Café  b4660a57e9f8cc613ae5b8f02bfce8634c763ab4
# 1044  Instituto Hondureño del Café  b4660a57e9f8cc613ae5b8f02bfce8634c763ab4
#
#                          certification_contact unit_of_measurement  \
# 364   7f521ca403540f81ec99daec7da19c2788393880                   m
# 459   7f521ca403540f81ec99daec7da19c2788393880                   m
# 602   70d3c0c26f89e00fdae6fb39ff54f0d2eb1c38ab                   m
# 848   7f521ca403540f81ec99daec7da19c2788393880                   m
# 882   7f521ca403540f81ec99daec7da19c2788393880                   m
# 975   7f521ca403540f81ec99daec7da19c2788393880                   m
# 1044  7f521ca403540f81ec99daec7da19c2788393880                   m
#
#      altitude_low_meters altitude_high_meters  altitude_mean_meters
# 364               1350.0               1350.0                1350.0
# 459               1350.0               1350.0                1350.0
# 602               1400.0               1850.0                1625.0
# 848               1350.0               1350.0                1350.0
# 882               1400.0               1400.0                1400.0
# 975               1450.0               1450.0                1450.0
# 1044              1450.0               1450.0                1450.0
#
# [7 rows x 43 columns]

# %%
coffee_data["country_of_origin"].value_counts(dropna = False)
# Out:
# country_of_origin
# Mexico                          236
# Colombia                        183
# Guatemala                       181
# Brazil                          132
# Taiwan                           75
# United States (Hawaii)           73
# Honduras                         53
# Costa Rica                       51
# Ethiopia                         44
# Tanzania, United Republic Of     40
# Uganda                           36
# Thailand                         32
# Nicaragua                        26
# Kenya                            25
# El Salvador                      21
# Indonesia                        20
# China                            16
# India                            14
# Malawi                           11
# United States                    10
# Peru                             10
# Vietnam                           8
# Myanmar                           8
# Haiti                             6
# Philippines                       5
# United States (Puerto Rico)       4
# Panama                            4
# Laos                              3
# Ecuador                           3
# Burundi                           2
# Papua New Guinea                  1
# Rwanda                            1
# Japan                             1
# Zambia                            1
# Mauritius                         1
# Cote d?Ivoire                     1
# NaN                               1
# Name: count, dtype: int64

# %%
coffee_data[coffee_data["country_of_origin"].isna()]
# Out:
#       species               owner country_of_origin farm_name lot_number mill  \
# 1197  Arabica  RACAFE & CIA S.C.A               NaN       NaN        NaN  NaN
#
#      ico_number company altitude region  ... color  category_two_defects  \
# 1197  3-37-1980     NaN      NaN    NaN  ...   NaN                     3
#
#                expiration certification_body  \
# 1197  February 29th, 2012           Almacafé
#
#                          certification_address  \
# 1197  e493c36c2d076bf273064f7ac23ad562af257a25
#
#                          certification_contact unit_of_measurement  \
# 1197  70d3c0c26f89e00fdae6fb39ff54f0d2eb1c38ab                   m
#
#      altitude_low_meters altitude_high_meters  altitude_mean_meters
# 1197                 NaN                  NaN                   NaN
#
# [1 rows x 43 columns]

# %%
# The country which is missing is Columbia according to my research
# source = "http://racafe.com.co/en/about-us/about-racafe/"
coffee_data["country_of_origin"] = coffee_data["country_of_origin"].fillna("Colombia")

# %%
coffee_data.loc[1197]
# Out:
# species                                                   Arabica
# owner                                          RACAFE & CIA S.C.A
# country_of_origin                                        Colombia
# farm_name                                                     NaN
# lot_number                                                    NaN
# mill                                                          NaN
# ico_number                                              3-37-1980
# company                                                       NaN
# altitude                                                      NaN
# region                                                        NaN
# producer                                                      NaN
# number_of_bags                                                149
# bag_weight                                                  70 kg
# in_country_partner                                       Almacafé
# harvest_year                                                  NaN
# grading_date                                      March 1st, 2011
# owner_1                                        Racafe & Cia S.C.A
# variety                                                       NaN
# processing_method                                             NaN
# aroma                                                        6.75
# flavor                                                       6.75
# aftertaste                                                   6.42
# acidity                                                      6.83
# body                                                         7.58
# balance                                                       7.5
# uniformity                                                   10.0
# clean_cup                                                    10.0
# sweetness                                                    10.0
# cupper_points                                                7.25
# total_cup_points                                            79.08
# moisture                                                      0.1
# category_one_defects                                            0
# quakers                                                       0.0
# color                                                         NaN
# category_two_defects                                            3
# expiration                                    February 29th, 2012
# certification_body                                       Almacafé
# certification_address    e493c36c2d076bf273064f7ac23ad562af257a25
# certification_contact    70d3c0c26f89e00fdae6fb39ff54f0d2eb1c38ab
# unit_of_measurement                                             m
# altitude_low_meters                                           NaN
# altitude_high_meters                                          NaN
# altitude_mean_meters                                          NaN
# Name: 1197, dtype: object

# %%
# I also spotted some errors in two other names - Côte d'Ivoire, and "Tanzania, United Republic of" is a little bit bland.

country_replacements = {
    "Tanzania, United Republic Of": "Tanzania",
    "Cote d?Ivoire": "Côte d'Ivoire"
}

coffee_data["country_of_origin"] = coffee_data['country_of_origin'].replace(country_replacements)

# %%
coffee_data["country_of_origin"].value_counts(dropna = False)
# Out:
# country_of_origin
# Mexico                         236
# Colombia                       184
# Guatemala                      181
# Brazil                         132
# Taiwan                          75
# United States (Hawaii)          73
# Honduras                        53
# Costa Rica                      51
# Ethiopia                        44
# Tanzania                        40
# Uganda                          36
# Thailand                        32
# Nicaragua                       26
# Kenya                           25
# El Salvador                     21
# Indonesia                       20
# China                           16
# India                           14
# Malawi                          11
# Peru                            10
# United States                   10
# Vietnam                          8
# Myanmar                          8
# Haiti                            6
# Philippines                      5
# Panama                           4
# United States (Puerto Rico)      4
# Ecuador                          3
# Laos                             3
# Burundi                          2
# Papua New Guinea                 1
# Japan                            1
# Zambia                           1
# Rwanda                           1
# Mauritius                        1
# Côte d'Ivoire                    1
# Name: count, dtype: int64

# %%
# Now I move on to the next column which is farm_name
coffee_data["farm_name"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1339 entries, 0 to 1338
# Series name: farm_name
# Non-Null Count  Dtype
# --------------  -----
# 980 non-null    object
# dtypes: object(1)
# memory usage: 10.6+ KB

# %%
# There are 359 NaN values in the "farm_name" column.
# That is why I will replace with "Unspecified"
1339 - 980
# Out:
# 359

# %%
coffee_data["farm_name"] = coffee_data["farm_name"].fillna("Unspecified")

# %%
coffee_data["farm_name"] == "Unspecified").value_counts()
# Out:
# farm_name
# False    980
# True     359
# Name: count, dtype: int64

# %%
coffee_data.loc[coffee_data["farm_name"] != "Unspecified", "farm_name"] = coffee_data.loc[coffee_data["farm_name"] != "Unspecified", "farm_name"].str.capitalize()

# %%
coffee_data["farm_name"].value_counts(dropna = False)
# Out:
# farm_name
# Unspecified                               359
# Various                                    47
# Rio verde                                  23
# Several                                    20
# Finca medina                               15
#                                          ...
# Producer group (approx. 1,000 farmers)      1
# Finca la fortuna                            1
# Cofradia                                    1
# Las ceibas                                  1
# Sierra madre                                1
# Name: count, Length: 572, dtype: int64

# %%
coffee_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1339 entries, 0 to 1338
# Data columns (total 43 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   species                1339 non-null   category
#  1   owner                  1339 non-null   object
#  2   country_of_origin      1339 non-null   object
#  3   farm_name              1339 non-null   object
#  4   lot_number             276 non-null    object
#  5   mill                   1021 non-null   object
#  6   ico_number             1180 non-null   object
#  7   company                1130 non-null   object
#  8   altitude               1113 non-null   object
#  9   region                 1280 non-null   object
#  10  producer               1107 non-null   object
#  11  number_of_bags         1339 non-null   int64
#  12  bag_weight             1339 non-null   object
#  13  in_country_partner     1339 non-null   object
#  14  harvest_year           1292 non-null   object
#  15  grading_date           1339 non-null   object
#  16  owner_1                1332 non-null   object
#  17  variety                1113 non-null   object
#  18  processing_method      1169 non-null   object
#  19  aroma                  1339 non-null   float64
#  20  flavor                 1339 non-null   float64
#  21  aftertaste             1339 non-null   float64
#  22  acidity                1339 non-null   float64
#  23  body                   1339 non-null   float64
#  24  balance                1339 non-null   float64
#  25  uniformity             1339 non-null   float64
#  26  clean_cup              1339 non-null   float64
#  27  sweetness              1339 non-null   float64
#  28  cupper_points          1339 non-null   float64
#  29  total_cup_points       1339 non-null   float64
#  30  moisture               1339 non-null   float64
#  31  category_one_defects   1339 non-null   int64
#  32  quakers                1338 non-null   float64
#  33  color                  1069 non-null   object
#  34  category_two_defects   1339 non-null   int64
#  35  expiration             1339 non-null   object
#  36  certification_body     1339 non-null   object
#  37  certification_address  1339 non-null   object
#  38  certification_contact  1339 non-null   object
#  39  unit_of_measurement    1339 non-null   object
#  40  altitude_low_meters    1109 non-null   float64
#  41  altitude_high_meters   1109 non-null   float64
#  42  altitude_mean_meters   1109 non-null   float64
# dtypes: category(1), float64(16), int64(3), object(23)
# memory usage: 440.9+ KB

# %%
# The lot_number has only 276 not Nan values which means that it is not a vital variable for analysis.
# That is why I think it will be better to remove it
coffee_data["lot_number"].value_counts(dropna = False)
# Out:
# lot_number
# NaN         1063
# 1             18
# 020/17         6
# 019/17         5
# 2              3
#             ...
# 7              1
# RKR            1
# RC AB          1
# Lavado 1       1
# Lavado 3       1
# Name: count, Length: 228, dtype: int64

# %%
coffee_data["lot_number"].nunique()
# Out:
# 227

# %%
coffee_data['lot_number'].notna().sum() / len(coffee_data) * 100
# Out:
# np.float64(20.612397311426438)

# %%
# As only 20% of the data have lot numbers, we can drop this column.
# Moreover, it is not useful for the purpose of analysis
coffee_data = coffee_data.drop(columns = ["lot_number"])

# %%
coffee_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1339 entries, 0 to 1338
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   species                1339 non-null   category
#  1   owner                  1339 non-null   object
#  2   country_of_origin      1339 non-null   object
#  3   farm_name              1339 non-null   object
#  4   mill                   1021 non-null   object
#  5   ico_number             1180 non-null   object
#  6   company                1130 non-null   object
#  7   altitude               1113 non-null   object
#  8   region                 1280 non-null   object
#  9   producer               1107 non-null   object
#  10  number_of_bags         1339 non-null   int64
#  11  bag_weight             1339 non-null   object
#  12  in_country_partner     1339 non-null   object
#  13  harvest_year           1292 non-null   object
#  14  grading_date           1339 non-null   object
#  15  owner_1                1332 non-null   object
#  16  variety                1113 non-null   object
#  17  processing_method      1169 non-null   object
#  18  aroma                  1339 non-null   float64
#  19  flavor                 1339 non-null   float64
#  20  aftertaste             1339 non-null   float64
#  21  acidity                1339 non-null   float64
#  22  body                   1339 non-null   float64
#  23  balance                1339 non-null   float64
#  24  uniformity             1339 non-null   float64
#  25  clean_cup              1339 non-null   float64
#  26  sweetness              1339 non-null   float64
#  27  cupper_points          1339 non-null   float64
#  28  total_cup_points       1339 non-null   float64
#  29  moisture               1339 non-null   float64
#  30  category_one_defects   1339 non-null   int64
#  31  quakers                1338 non-null   float64
#  32  color                  1069 non-null   object
#  33  category_two_defects   1339 non-null   int64
#  34  expiration             1339 non-null   object
#  35  certification_body     1339 non-null   object
#  36  certification_address  1339 non-null   object
#  37  certification_contact  1339 non-null   object
#  38  unit_of_measurement    1339 non-null   object
#  39  altitude_low_meters    1109 non-null   float64
#  40  altitude_high_meters   1109 non-null   float64
#  41  altitude_mean_meters   1109 non-null   float64
# dtypes: category(1), float64(16), int64(3), object(22)
# memory usage: 430.5+ KB

# %%
coffee_data.mill.value_counts(dropna = False)
# Out:
# mill
# NaN                                                     318
# beneficio ixchel                                         90
# dry mill                                                 39
# trilladora boananza                                      38
# ipanema coffees                                          16
#                                                        ...
# las minas                                                 1
# la distancia                                              1
# coeb koperativ ekselsyo basen (350 members)               1
# la esperanza, municipio juchique de ferrer, veracruz      1
# wolensu                                                   1
# Name: count, Length: 460, dtype: int64

# %%
coffee_data.mill = coffee_data.mill.fillna("Unknown")

# %%
coffee_data.loc[coffee_data.mill != "Unknown", "mill"] = coffee_data.loc[coffee_data.mill != "Unknown", "mill"].str.upper()

# %%
# Now let's look at the ico_number
# We have NaN values again
coffee_data["ico_number"].value_counts(dropna = False)
# Out:
# ico_number
# NaN               159
# 0                  77
# Taiwan             31
# 2222               11
# -                   9
#                  ...
# 1104820070          1
# 220456              1
# 0016-2722-0001      1
# 5-545-0015          1
# 11111               1
# Name: count, Length: 847, dtype: int64

# %%
coffee_data["ico_number"].info()
# 152 records do not have values
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1339 entries, 0 to 1338
# Series name: ico_number
# Non-Null Count  Dtype
# --------------  -----
# 1180 non-null   object
# dtypes: object(1)
# memory usage: 10.6+ KB

# %%
coffee_data["ico_number"].unique()
# Out:
# array(['2014/2015', nan, '010/0338', '2014/15', 'unknown', '010/0056',
#        '100181006', '5-562-0015', '0', '002/1251/0073', '010/0056/Sidamo',
#        '13-111-053', 'Taiwan', '790-0013', 'A019116', '002/1251/0068',
#        '5818009', '220452', 'HDOA 210128 Kona Fancy', '010/0170',
#        '01-011-512', '002/1352/0045', 'NIL', '002/1251/0071', 'NONE', 'x',
#        '010/0145', '11/23/0252', '3-68-0215', '11/1886/03', '11-853-155',
#        '490', '030-0537-2066', '25072012', '09 – 060-24', '220451',
#        '290503', '3707361715', '2015', '11-52-492', '220453',
#        '002/1251/0072', '9-060-60D-L-1D', '11999144', '5-562-0006',
#        '5-562-0016', '37/672/0017', '37/00597/0252 - AB FAQ Q certified',
#        '010/0157', '010/0001/0022', '11/23/0177', '3-68-0102',
#        '3-79-0634', '11-30-0593', '495', '3-59-3115', 'KP 022014',
#        '3-59-0951', '010/0058/Sidamo', 'HDOA 210310', '3-37-1829',
#        '37/672/0016', '002/1251/0242', '016-2484-04', 'HDOA#210306',
#        '11-194-0014', '3-37-0277', '3-37-4824', 'C47', '3-37-0416',
#        '1104385872', '002/1251/0070', '002/1251/0066', '37/00395/0335',
#        '220457', 'KE 9143', '13-63-174', '9-29-1986', '1-053-0222',
#        '09-392-69', '5-423-0128', '11/08/0109', '5-114-0171', '33',
#        '58180422', '5-0048-0052', '5-1106-0011', '3-79-0543',
#        '11/23/1088', '11/1886/02', '703816889, 108282,703816891',
#        '3-37-1724', '3-37-1291', 'KE 3127', '11/972/26', '11-23-0291',
#        '3-79-0542', '3-37-0930', '3-68-0224', '3-68-0005',
#        '002/1251/0069', '002/1251/0076', '5-0015-0029',
#        '035/170/5071146\u2060\u2060\u2060\u2060', '5-114-0170', '01-4008',
#        '1', '11/23/0398', '1104548679', '2222', '11/326/06', 'mmm',
#        'TEST', '5-0015-0231', 'To be advice', '3-59-0318', '3-37-2940',
#        '2234501 KONA FANCY', '1506545936', '13-111-023', '03-05-0845',
#        '13-111-032', '3-37-1704', '3-59-2235', '3-68-0225', '1506680144',
#        '002/1251/0360', '11-897-10', '3-59-3461', '11/11711/59',
#        '11/52/709', '3-37-0637', '3-37-4823', '01-3576', '3-59-2270',
#        'C46', 'C12', '11/23/0561', '3-68-0290', '2230302 KONA NO. 1',
#        '11/23/0365', '3-37-3825', '5-818-0450', '11/52/1170', '11/752/01',
#        '11/23/0335', '3-37-4173', '017/176/165', '002/1495/0607',
#        '5-025-0111', 'C31', '329', '11/43984/0001', '37-0569-2730',
#        '2131202', 'non', '015/1691/006', '5-025-0048', 'C17',
#        '14-3-79-1034', '11/23/0233', '11/23/0240', '3-37-1980',
#        '017-053-0046', 'C28', '13-123-238', '11-52-121', 'HDOA 210282',
#        '11/15/0293', '13-154-234', 'not applicable', '002/4542/0049',
#        '11-951-136', '002/135-2/0182', '11/52/492', '1405793051',
#        '13-63-60', 'CNY', '1405675414', '027/01/601', 'A053',
#        '11/23/0795', '2135405', '010/0058', '002/143-0/0058',
#        '017/117/018', 'KPP021114', '11-23-1972', '1702801679',
#        '017-053-0125', '13-63-70', '11/23/1170', '1104362940',
#        '1405791535', '1104367469', '11/23/0582', '002/1352/0226', '17',
#        '1401045726', '017/001/1638', '0016-2050-0001', '03-01-2700',
#        'KP022414', '1506729960', '017/191/488', '1104276076',
#        'HDOA 220468 Kona Prime', '10703510', '030-0595-0508', '5-066-038',
#        '1405811686', 'FINCA MEDINA 11/11711/01-LOGO APCA', '1506622214',
#        '11/23/0508', '9', '11/23/0957', '1702807163', '1104363350',
#        '1104379888', '3-68-0153', '11-194-0008', '017/176/160', '68-0197',
#        '145092', '11/23/0358', '3-279-390', '1104340088', '1104275271',
#        '11/23/0122', '11/23/0168', '2728', '016/2362/0057', '1405792893',
#        '1207093598', '11-951-388', '13-117-87', '030-0582-0050',
#        '2074632', 'F07016865', '017-053-0211/053-0212',
#        'Specialty Coffee Association of America', '11/23/1020',
#        '11042707999', 'LOUIS88', '1104374276', '017-053', '1506502938',
#        '703817078, 703817042, 700137443', 'HDOA 210542', '0016-2795-0008',
#        '1506868415', 'K#1 21614', '11/23/0334', '11/23/0101', 'KP120314',
#        '2209401 KONA PRIME', '1104341113', '13-117-88', 'KF 21614',
#        '1506558883', '03/01/1632', '5-545-0007', '11/23/0121', '16039',
#        '11/23/0333', 'KP3150140', '110548082', '11/426/1', '1506558882',
#        '30', '14/7/2015/172', '016/2362/0051', '11/23/01', 'KPBP 21114',
#        'Specialty Coffee Association', '1405792248', '1104372556',
#        '11/23/0768', '2670', 'F07008657', 'KPBP 022414', '11/23/0796',
#        '1104820070', '220456', '0016-2722-0001', '5-545-0015', '11111',
#        '1104351023', '0016-2847-0001', '1104328663',
#        '017-053-0211/ 017-053-0212', '11/853/165', '14/1148/2017/21',
#        '0000', '14/1148/2017/18', '14/1148/2016/17', '14/1148/2016/12',
#        '14-1118-2014-0087'], dtype=object)

# %%
# There are NaN values so I replace them with "Unknown"
coffee_data["ico_number"] = coffee_data["ico_number"].fillna("Unknown")

# %%
coffee_data["ico_number"].unique()
# Out:
# array(['2014/2015', 'Unknown', '010/0338', '2014/15', 'unknown',
#        '010/0056', '100181006', '5-562-0015', '0', '002/1251/0073',
#        '010/0056/Sidamo', '13-111-053', 'Taiwan', '790-0013', 'A019116',
#        '002/1251/0068', '5818009', '220452', 'HDOA 210128 Kona Fancy',
#        '010/0170', '01-011-512', '002/1352/0045', 'NIL', '002/1251/0071',
#        'NONE', 'x', '010/0145', '11/23/0252', '3-68-0215', '11/1886/03',
#        '1104379888', '3-68-0153', '11-194-0008', '017/176/160', '68-0197',
#        '145092', '11/23/0358', '3-279-390', '1104340088', '1104275271',
#        '11/23/0122', '11/23/0168', '2728', '016/2362/0057', '1405792893',
#        '1207093598', '11-951-388', '13-117-87', '030-0582-0050',
#        '2074632', 'F07016865', '017-053-0211/053-0212',
#        'Specialty Coffee Association of America', '11/23/1020',
#        '11042707999', 'LOUIS88', '1104374276', '017-053', '1506502938',
#        '703817078, 703817042, 700137443', 'HDOA 210542', '0016-2795-0008',
#        '1506868415', 'K#1 21614', '11/23/0334', '11/23/0101', 'KP120314',
#        '2209401 KONA PRIME', '1104341113', '13-117-88', 'KF 21614',
#        '1506558883', '03/01/1632', '5-545-0007', '11/23/0121', '16039',
#        '11/23/0333', 'KP3150140', '110548082', '11/426/1', '1506558882',
#        '30', '14/7/2015/172', '016/2362/0051', '11/23/01', 'KPBP 21114',
#        'Specialty Coffee Association', '1405792248', '1104372556',
#        '11/23/0768', '2670', 'F07008657', 'KPBP 022414', '11/23/0796',
#        '1104820070', '220456', '0016-2722-0001', '5-545-0015', '11111',
#        '1104351023', '0016-2847-0001', '1104328663',
#        '017-053-0211/ 017-053-0212', '11/853/165', '14/1148/2017/21',
#        '0000', '14/1148/2017/18', '14/1148/2016/17', '14/1148/2016/12',
#        '14-1118-2014-0087'], dtype=object)

# %%
# Replace all symbols such as '-' with '/' as this is the correct format
import re
coffee_data['ico_number'] = coffee_data['ico_number'].str.replace(r'(?<=\d)[^\d]+(?=\d)', '/', regex=True)

# %%
coffee_data['ico_number'].unique()
# Out:
# array(['2014/2015', 'Unknown', '010/0338', '2014/15', 'unknown',
#        '010/0056', '100181006', '5/562/0015', '0', '002/1251/0073',
#        '010/0056/Sidamo', '13/111/053', 'Taiwan', '790/0013', 'A019116',
#        '002/1251/0068', '5818009', '220452', 'HDOA 210128 Kona Fancy',
#        '010/0170', '01/011/512', '002/1352/0045', 'NIL', '002/1251/0071',
#        'NONE', 'x', '010/0145', '11/23/0252', '3/68/0215', '11/1886/03',
#        '11/853/155', '490', '030/0537/2066', '25072012', '09/060/24',
#        '220451', '290503', '3707361715', '2015', '11/52/492', '220453',
#        '002/1251/0072', '9/060/60/1D', '11999144', '5/562/0006',
#        '5/562/0016', '37/672/0017', '37/00597/0252 - AB FAQ Q certified',
#        '010/0157', '010/0001/0022', '11/23/0177', '3/68/0102',
#        '3/79/0634', '11/30/0593', '495', '3/59/3115', 'KP 022014',
#        '3/59/0951', '010/0058/Sidamo', 'HDOA 210310', '3/37/1829',
#        '37/672/0016', '002/1251/0242', '016/2484/04', 'HDOA#210306',
#        '11/194/0014', '3/37/0277', '3/37/4824', 'C47', '3/37/0416',
#        '1104385872', '002/1251/0070', '002/1251/0066', '37/00395/0335',
#        '220457', 'KE 9143', '13/63/174', '9/29/1986', '1/053/0222',
#        '09/392/69', '5/423/0128', '11/08/0109', '5/114/0171', '33',
#        '58180422', '5/0048/0052', '5/1106/0011', '3/79/0543',
#        '11/23/0101', '13/117/88', '03/01/1632', '5/545/0007',
#        '11/23/0121', '11/23/0333', '11/426/1', '016/2362/0051',
#        '11/23/01', '11/23/0768', '11/23/0796', '0016/2722/0001',
#        '5/545/0015', '0016/2847/0001', '11/853/165'], dtype=object)

# %%
coffee_data['ico_number'].value_counts()
# Out:
# ico_number
# Incorrect format    731
# 002/4177/0150         7
# 002/1660/0105         7
# 002/1660/0080         6
# 13/111/053            5
#                    ...
# 11/23/0333            1
# 5/545/0007            1
# 03/01/1632            1
# 11/23/0334            1
# 002/1251/0068         1
# Name: count, Length: 503, dtype: int64

# %%
coffee_data.company.value_counts(dropna = False)
# Out:
# company
# NaN                                      209
# unex guatemala, s.a.                      86
# ipanema coffees                           50
# exportadora de cafe condor s.a            40
# racafe & cia s.c.a                        40
#                                         ...
# kasozi coffee farmers association          1
# nitubaasa ltd                              1
# mannya coffee project                      1
# yidnekachew debessa coffee plantation      1
# global opportunity fund                    1
# Name: count, Length: 282, dtype: int64

# %%
coffee_data.company = coffee_data.company.str.upper()

# %%
coffee_data[coffee_data.company.isna()]
# Out:
#       species                          owner       country_of_origin  \
# 2     Arabica       GROUNDS FOR HEALTH ADMIN               Guatemala
# 5     Arabica                      JI-AE AHN                  Brazil
# 7     Arabica    ETHIOPIA COMMODITY EXCHANGE                Ethiopia
# 8     Arabica    ETHIOPIA COMMODITY EXCHANGE                Ethiopia
# 13    Arabica       GROUNDS FOR HEALTH ADMIN  United States (Hawaii)
# ...       ...                            ...                     ...
# 1288  Arabica  JORGE OCTAVIO ESCAMILLA PRADO                  Mexico
# 1289  Arabica   MYRNA ROXANA GALVEZ GONZALEZ                  Mexico
# 1290  Arabica              EUGENE HOLMAN PEW                  Mexico
# 1297  Arabica        MYRIAM KAPLAN-PASTERNAK                   Haiti
# 1300  Arabica  RICARDO AARON SAMPIERI MARINI                  Mexico
#
#                                      farm_name  \
# 2     san marcos barrancas "san cristobal cuch
# 5                                  Unspecified
# 7                                        aolme
# 8                                        aolme
# 13                               arianna farms
# ...                                        ...
# 1288                                las ceibas
# 1289                    la marina-el orizabeño
# 1290                              rancho vigia
# 1297                              2000 farmers
# 1300                                 la morena
#
#                                                 mill        ico_number  \
# 2                                            Unknown  Incorrect format
# 5                                            Unknown  Incorrect format
# 7                                            C.P.W.E  Incorrect format
# 8                                            C.P.W.E  Incorrect format
# 13                                           Unknown  Incorrect format
# ...                                              ...               ...
# 1288                             CATUAI AMARILLO SSS  Incorrect format
# 1289  BENEFICIO DE CAFÉ TECOXOLCO S. DE R.L. DE C.V.  Incorrect format
# 1290                                    RANCHO VIGIA  Incorrect format
# 1297        COOPERATIVE AGRO-INDUSTRIELLE DE MARMELA  Incorrect format
# 1300                        TLAMATOCA, HUTUSCO, VER.  Incorrect format
#
#      company       altitude              region  \
# 2        NaN  1600 - 1800 m                 NaN
# 5        NaN            NaN                 NaN
# 7        NaN      1570-1700              oromia
# 8        NaN      1570-1700             oromiya
# 13       NaN        2000 ft                kona
# ...      ...            ...                 ...
# 1288     NaN           1140  chocaman, veracruz
# 1289     NaN           1200              xalapa
# 1290     NaN           1250            coatepec
# 1297     NaN     640m-1400m           marmelade
# 1300     NaN           1800            veracruz
#
#                                                producer  ...         color  \
# 2                                                   NaN  ...           NaN
# 5                                                   NaN  ...  Bluish-Green
# 7             Bazen Agricultural & Industrial Dev't Plc  ...           NaN
# 8             Bazen Agricultural & Industrial Dev't Plc  ...           NaN
# 13                         Robert, Sharon, Arianna Wood  ...           NaN
# ...                                                 ...  ...           ...
# 1288                      JORGE OCTAVIO ESCAMILLA PRADO  ...         Green
# 1289                       MYRNA ROXANA GÁLVEZ GONZÁLEZ  ...           NaN
# 1290                                  EUGENE HOLMAN PEW  ...         Green
# 1297  Asosyasyon Plantè Kafe Krètapen (APCAP) ;Asosy...  ...           NaN
# 1300                      RICARDO AARON SAMPIERI MARINI  ...         Green
#
#      category_two_defects            expiration  \
# 2                       0        May 31st, 2011
# 5                       1   September 3rd, 2014
# 7                       0   September 2nd, 2011
# 8                       0   September 2nd, 2011
# 13                      2        May 31st, 2011
# ...                   ...                   ...
# 1288                   11  September 10th, 2013
# 1289                   27  September 17th, 2013
# 1290                   19      August 1st, 2013
# 1297                    0     August 22nd, 2012
# 1300                    0       July 11th, 2013
#
#                       certification_body  \
# 2           Specialty Coffee Association
# 5     Specialty Coffee Institute of Asia
# 7            Ethiopia Commodity Exchange
# 8            Ethiopia Commodity Exchange
# 13          Specialty Coffee Association
# ...                                  ...
# 1288                             AMECAFE
# 1289                             AMECAFE
# 1290                             AMECAFE
# 1297        Specialty Coffee Association
# 1300                             AMECAFE
#
#                          certification_address  \
# 2     36d0d00a3724338ba7937c52a378d085f2172daa
# 5     726e4891cf2c9a4848768bd34b668124d12c4224
# 7     a176532400aebdc345cf3d870f84ed3ecab6249e
# 8     a176532400aebdc345cf3d870f84ed3ecab6249e
# 13    36d0d00a3724338ba7937c52a378d085f2172daa
# ...                                        ...
# 1288  59e396ad6e22a1c22b248f958e1da2bd8af85272
# 1289  59e396ad6e22a1c22b248f958e1da2bd8af85272
# 1290  59e396ad6e22a1c22b248f958e1da2bd8af85272
# 1297  36d0d00a3724338ba7937c52a378d085f2172daa
# 1300  59e396ad6e22a1c22b248f958e1da2bd8af85272
#
#                          certification_contact unit_of_measurement  \
# 2     0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 5     b70da261fcc84831e3e9620c30a8701540abc200                   m
# 7     61bbaf6a9f341e5782b8e7bd3ebf76aac89fe24b                   m
# 8     61bbaf6a9f341e5782b8e7bd3ebf76aac89fe24b                   m
# 13    0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                  ft
# ...                                        ...                 ...
# 1288  0eb4ee5b3f47b20b049548a2fd1e7d4a2b70d0a7                   m
# 1289  0eb4ee5b3f47b20b049548a2fd1e7d4a2b70d0a7                   m
# 1290  0eb4ee5b3f47b20b049548a2fd1e7d4a2b70d0a7                   m
# 1297  0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 1300  0eb4ee5b3f47b20b049548a2fd1e7d4a2b70d0a7                   m
#
#      altitude_low_meters  altitude_high_meters  altitude_mean_meters
# 2                 1600.0                1800.0                1700.0
# 5                    NaN                   NaN                   NaN
# 7                 1570.0                1700.0                1635.0
# 8                 1570.0                1700.0                1635.0
# 13                 609.6                 609.6                 609.6
# ...                  ...                   ...                   ...
# 1288              1140.0                1140.0                1140.0
# 1289              1200.0                1200.0                1200.0
# 1290              1250.0                1250.0                1250.0
# 1297               640.0                1400.0                1020.0
# 1300              1800.0                1800.0                1800.0
#
# [209 rows x 42 columns]

# %%
coffee_data.company = coffee_data.company.fillna("Not mentioned")

# %%
coffee_data.company.value_counts(dropna = False)
# Out:
# company
# Not mentioned                            209
# UNEX GUATEMALA, S.A.                      86
# IPANEMA COFFEES                           50
# EXPORTADORA DE CAFE CONDOR S.A            40
# RACAFE & CIA S.C.A                        40
#                                         ...
# KASOZI COFFEE FARMERS ASSOCIATION          1
# NITUBAASA LTD                              1
# MANNYA COFFEE PROJECT                      1
# YIDNEKACHEW DEBESSA COFFEE PLANTATION      1
# GLOBAL OPPORTUNITY FUND                    1
# Name: count, Length: 282, dtype: int64

# %%
coffee_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1339 entries, 0 to 1338
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   species                1339 non-null   category
#  1   owner                  1339 non-null   object
#  2   country_of_origin      1339 non-null   object
#  3   farm_name              1339 non-null   object
#  4   mill                   1339 non-null   object
#  5   ico_number             1339 non-null   object
#  6   company                1339 non-null   object
#  7   altitude               1113 non-null   object
#  8   region                 1280 non-null   object
#  9   producer               1107 non-null   object
#  10  number_of_bags         1339 non-null   int64
#  11  bag_weight             1339 non-null   object
#  12  in_country_partner     1339 non-null   object
#  13  harvest_year           1292 non-null   object
#  14  grading_date           1339 non-null   object
#  15  owner_1                1332 non-null   object
#  16  variety                1113 non-null   object
#  17  processing_method      1169 non-null   object
#  18  aroma                  1339 non-null   float64
#  19  flavor                 1339 non-null   float64
#  20  aftertaste             1339 non-null   float64
#  21  acidity                1339 non-null   float64
#  22  body                   1339 non-null   float64
#  23  balance                1339 non-null   float64
#  24  uniformity             1339 non-null   float64
#  25  clean_cup              1339 non-null   float64
#  26  sweetness              1339 non-null   float64
#  27  cupper_points          1339 non-null   float64
#  28  total_cup_points       1339 non-null   float64
#  29  moisture               1339 non-null   float64
#  30  category_one_defects   1339 non-null   int64
#  31  quakers                1338 non-null   float64
#  32  color                  1069 non-null   object
#  33  category_two_defects   1339 non-null   int64
#  34  expiration             1339 non-null   object
#  35  certification_body     1339 non-null   object
#  36  certification_address  1339 non-null   object
#  37  certification_contact  1339 non-null   object
#  38  unit_of_measurement    1339 non-null   object
#  39  altitude_low_meters    1109 non-null   float64
#  40  altitude_high_meters   1109 non-null   float64
#  41  altitude_mean_meters   1109 non-null   float64
# dtypes: category(1), float64(16), int64(3), object(22)
# memory usage: 430.5+ KB

# %%
coffee_data.altitude.unique()
# Out:
# array(['1950-2200', '1600 - 1800 m', '1800-2200', nan, '1570-1700',
#        '1795-1850', '1855-1955', 'meters above sea level: 1.872',
#        'meters above sea level: 1.943', '2000 ft',
#        'meters above sea level: 2.080', '1200-1800m', '1450',
#        '1700-2000m', 'meters above sea level: 2.019', '1300 msnm', '1320',
#        'meters above sea level: 2.112', '1250m', '1950', '1400', '1200',
#        '1300', '1750-1800', '1800', 'meters above sea level: 1.941',
#        '1.2', '1000 m', '1754', '900-1500m', '1520m-2200m', '1400-1900m',
#        '1500-2000 m', '1400ft', '1400-1900', '1800 msnm', '1600',
#        '1800-2000', '5000', '4650', '1700 mts', '1500 meters',
#        '1300~1400 m.s.l', '1680', '1900m', '5600-5760 metros', '1400 m',
#        '1700', '1770', 'above 1600 m', 'above 1200 m', '1550 msnm',
#        '1550', '1250-1400 meter', '1400 msm', '2.560 msnm', '2136 msnm',
#        '1900', '-1', '1580', '1100m', '1400 masl', '3500-5200 feet',
#        'de 1600 a 1950 msnm', '800 m', '1620m', '1200m', '350',
#        '1450 msnm', '1200 mts', '800-1050m', '1350', '170', '1150',
#        '1750', '1750m', '2000', '4300', '1700-1850m', '1500', '5000 ft.',
#        '4000 psn', '1600 a 1900 msnm', '1750 msnm', '1450 ~ 1700 m',
#        '1300m', 'above 1100m', '2000 m', 'mmm', 'test', '900', '442 msnm',
#        '1200m to 1350m', '900-1200m', '3600-6200 ft', '4400-4700 ft',
#        '1000', '2560', '3607', '4000 psnm', '1170', '1700m', '3664',
#        '1565', '3280', 'de 900 a 1100 msnm', '1850', '1545-1668 masl',
#        '1530', "approx. 1'500 metres a.s.l.", '894m - 1183m',
#        '1500-1700m', '442', '968', '1480', '1800m', '5440 - 5760 metros',
#        '1550 m', '1260', '1700 msnm', '1650', '890', '934', '950公尺',
#        '2527', '1', '480-570m', '1650-1703', '1200-1400',
#        '800 meters above sea level', '1218', '1.250 m', '4921ft', '750',
#        '2800 ft', '1500-1600', '700', '1300 mts', '1600 m.s.n.m',
#        '1600 msnm', '1250', '800++', '1550-1700m', '4451 metros',
#        '1800 - 2000', '1100', '1200-1600masl', '3702',
#        'de 1.600 a 1.950 msnm', '1799', '4000', '1400m',
#        '1600 on average', '1850 msnm', '1400 mts', '940', '4600 ft.',
#        '439', '1330', '1813', '1500 msnm', '900-1200mtr', '1227',
#        '1650 msnm', '1100-1300', '4200 feet', '1000 msnm', '1880', '2100',
#        '1261', '800公尺', '1483', '175', '1600-1800msnm', '1880 msnm',
#        '1800 m.s.n.m', '1901', '16.8', '1500msnm', '1400-1900 psn',
#        "approx.1'500 metres a.s.l.", '1653', '1450 msnn', '5000 pies',
#        '532', '1089', '1380', '1000m', '950m', '900m', '1850 m', '905',
#        '700-800m', '1300 m', 'de 1.600 a 1.950 msn', '1300-1400m', '894',
#        '872', '1473', '1645', '1300 a 1800 metros sobre el nivel del mar',
#        '4500 pies', '900-1100', '1600 - 1950 msnm', '1500-1750 msnm',
#        '4500', '1050 - 1850 msnm', '775', '1200 masl',
#        '1600 + meters above sea level', '1059', '1300 meters',
#        '11000 metros', '5440-5760 metros', '1248', '1040m', '1040',
#        '4000psn', '1200-2000m', '1200 m', '1800 mts',
#        '1400 meter above sea level', '518', '650', '1442 m', '1.65',
#        '1400 thru 1850', '1200公尺', '1296', '1400- 1900', '1240 m', '950',
#        '1800 meters (5900', '1050', '200 m', '1200-1300m dpl',
#        '1400-1500 m', '1317', '900-1050m', '1679', '2285', 'huanuco',
#        '1560', '1750 m.s.n.m', '1396', '982', '1268', '5500 metros',
#        '1450 m', '600 m', '5500-6000 psnm', '441', '1200 a 1400', '1180m',
#        '650 m', '1338', '533', '4563', '1500-1800', '1200-1600m', '1144',
#        '1200-1400 masl', '1500 - 1700', '1.3', '944', '1300- 1400',
#        '2500m', '600m', '1400 m.s.n.m.', '600-700 m', '1050m', '1020',
#        '1300 a 1800 mtrs. a nivel del mar', '1877', '1000-1500m', '981',
#        '690', '973', '4001', '1350-1500', '1400 msnm', '700m', '1556m',
#        '1550 meters', 'de 1.600 a 1950 msnm', '900-950m',
#        '1600-1800 msnm', '774', '150 m', '750 m', '190164', '800',
#        '850 m', '4500-6000 feet', '160-200m', '4000 ft', '1200 msm',
#        '1599m', '900 m', '400-1250m', '1.25', '1050 - 1850', '110公尺',
#        '1422', '1550 mts.', '1550 meter', '763', '1130', '680',
#        '1400 msn', '5000 f', '100/2000', '1450 mals', '990-1000m', '0',
#        '695', '1100 m.o.s.l.', '5600 feet', '1456', '1500 mts', '1642',
#        '758m', '1350 snn', '1525 m', '1100 m', '200', '3500 ft', '550公尺',
#        'between 700 and 1400 meters', '688 m', '300 m', '1186', '1210',
#        '100', '3825', '1100.00 mosl', '1450 masl', '1680m',
#        '~1000 meters', '1200-1500', '1.85', '4540 metros', '50', '280',
#        '1250 m', '3800', '4000 p.s.n.m.', '6100 metros', '600公尺', '1450m',
#        '995', '3000 ft', '4287', '900 m.s.n.m.', '700 m', '808',
#        '1100 - 1275 mts', '850公尺', '250 m', '3845', '1300 to 1500 meters',
#        '1901.64', '800-1200', '500-700m', '1022', '975', '1264',
#        '3500 - 5200 feet', '700m公尺', '850', '12oo', '800m', '1600 meters',
#        '4000 p.s.n.m', '1200 meters', '750-800 m', '900-1500 masl',
#        '3500', '1000+ meters', '1280', '1140', '640m-1400m',
#        '1000 meters', '~350m', '1488', '3170', '1212', '1200-1300',
#        "3000'", '750m', '3140', '900-1300', '1095', '1367', '1745', '40',
#        '795 meters'], dtype=object)

# %%
# Define all replacement rules in one place
unit_map = {
    "msnm": "m",
    "m.s.n.m": "m",
    "masl": "m",
    "mts": "m",
    "mtrs": "m",
    "meter": "m",
    "meters": "m",
    "metros": "m",
    "公尺": "m",
    "pies": "ft",
    "pies.": "ft",
    "ft.": "ft",
    "feet": "ft",
    "ft": "ft",  # normalize even this
    "psn": "ft",
    "psnm": "ft",
    "p.s.n.m.": "ft",
    "p.s.n.m": "ft"
}

def normalize_units(value):
    for key, val in unit_map.items():
        value = value.replace(key, val)
    return value

def clean_altitude(value):
    if pd.isnull(value):
        return np.nan

    value = str(value).lower()

    # Normalize units
    value = normalize_units(value)

    # Clean approx and extra symbols
    value = re.sub(r"approx(?:\.|imately)?", "", value)
    value = re.sub(r"[~']", "", value)
    value = re.sub(r"[^0-9\.\-\sftm]", "", value)  # remove strange symbols

    # Extract numbers
    nums = re.findall(r"\d+(?:\.\d+)?", value)
    if not nums:
        return np.nan

    nums = [float(n) for n in nums]

    # Handle ranges (take average)
    avg = sum(nums) / len(nums)

    # Check if it's in feet
    if 'ft' in value:
        avg *= 0.3048  # Convert to meters

    return round(avg, 2)

# %%
coffee_data.altitude = coffee_data.altitude.apply(clean_altitude)

# %%
coffee_data.altitude.value_counts(dropna = False)
# Out:
# altitude
# NaN       229
# 1200.0     67
# 1100.0     54
# 1400.0     52
# 1300.0     50
#          ...
# 1095.0      1
# 1367.0      1
# 1745.0      1
# 40.0        1
# 795.0       1
# Name: count, Length: 222, dtype: int64

# %%
coffee_data.altitude.astype(float)
# Out:
# 0       2075.0
# 1       2075.0
# 2       1700.0
# 3       2000.0
# 4       2075.0
#          ...
# 1334       NaN
# 1335      40.0
# 1336     795.0
# 1337       NaN
# 1338       NaN
# Name: altitude, Length: 1339, dtype: float64
