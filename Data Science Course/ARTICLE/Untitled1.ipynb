# %%
# !pip install --upgrade pip setuptools wheel
# !pip install allennlp==2.8.0 allennlp-models==2.8.0
# !pip install transformers datasets spacy==3.2.4 scikit-learn
# Out:
# ...
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 6.2 MB/s eta 0:00:00
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# ERROR: To modify pip, please run the following command:
# C:\Users\aneli\anaconda3\python.exe -m pip install --upgrade pip setuptools wheel
# ...
#   Using cached allennlp-2.8.0-py3-none-any.whl.metadata (17 kB)
# ...
# INFO: pip is looking at multiple versions of allennlp to determine which version is compatible with other requirements. This could take a while.
# ERROR: Ignored the following versions that require a different python version: 0.2.0 Requires-Python ==3.6
# ERROR: Could not find a version that satisfies the requirement torch<1.11.0,>=1.6.0 (from allennlp) (from versions: 2.6.0, 2.7.0, 2.7.1, 2.8.0)
# ...
