# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Acquisition Demos
# ## Live Demos

# %% [markdown]
# Text.
#
# **Bold text**
#
# $$ y = ax^2 + bx + c$$
#
# 1. List
# 2. List 2
# 3. List 3

# %%
favourite_number = 42
print(42)
# Out:
# 42

# %%
print(favourite_number * 10)
# Out:
# 420

# %%
pd.read_csv("data/accidents.csv")
# Out:
#   Miles from Home  % of Accidents
# 0     less than 1              23
# 1          1 to 5              29
# 2         6 to 10              17
# 3        11 to 15               8
# 4        16 to 20               6
# 5         over 20              17

# %%
pd.read_csv("data/archive/books.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 pd.read_csv("data/archive/books.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %% [markdown]
# # Assistant
# This error occurs when pandas encounters inconsistent delimiters or field counts in a CSV file. In this case, line 3350 has 13 fields when pandas expected 12 fields based on the header or other rows.
#
# The error is likely caused by one of these issues:
# 1. A field in line 3350 contains a comma within quoted text
# 2. There's an actual extra column in that line
# 3. The CSV file might have inconsistent formatting
#
# Would you like me to provide the corrected code?

# %%
# Assistant
# Option 1: Use error_bad_lines=False (in newer pandas versions, this is skiprows_bad_lines=True)
pd.read_csv("data/archive/books.csv", on_bad_lines='skip')
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11118   45631   Expelled from Eden: A William T. Vollmann Reader
# 11119   45633                        You Bright and Risen Angels
# 11120   45634                    The Ice-Shirt (Seven Dreams #1)
# 11121   45639                                        Poor People
# 11122   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating  \
# 0                             J.K. Rowling/Mary GrandPré            4.57
# ...

# %%
pd.read_csv("data/books-dataset/Books.csv")
# Out:
#                                                   title  \
# 0                              Fictional Points of View
# 1                Science Fiction and Fantasy Literature
# 2                  Library of Congress Subject Headings
# 3                  Library of Congress Subject Headings
# 4     Fictional Space in the Modernist and Post-mode...
# ...                                                 ...
# 2044                                     The Index Card
# 2045                                 The Road to Wealth
# 2046                             The Success Principles
# 2047                             The Courage to Be Rich
# 2048                                   The Money Manual
#
#                                                  author pages  \
# 0                                        Peter Lamarque   252
# 1        R. Reginald, Douglas Menville, Mary A. Burgess   802
# 2     Library of Congress. Cataloging Policy and Sup...  1662
# ...

# %%
books_data = pd.read_csv("data/books-dataset/Books.csv")

# %%
books_data
# Out:
#                                                   title  \
# 0                              Fictional Points of View
# 1                Science Fiction and Fantasy Literature
# 2                  Library of Congress Subject Headings
# 3                  Library of Congress Subject Headings
# 4     Fictional Space in the Modernist and Post-mode...
# ...                                                 ...
# 2044                                     The Index Card
# 2045                                 The Road to Wealth
# 2046                             The Success Principles
# 2047                             The Courage to Be Rich
# 2048                                   The Money Manual
#
#                                                  author pages  \
# 0                                        Peter Lamarque   252
# 1        R. Reginald, Douglas Menville, Mary A. Burgess   802
# 2     Library of Congress. Cataloging Policy and Sup...  1662
# ...

# %%
books_data.shape
# Out:
# (2049, 11)

# %%
type(books_data)
# Out:
# pandas.core.frame.DataFrame

# %%
books_data.title
# Out:
# 0                                Fictional Points of View
# 1                  Science Fiction and Fantasy Literature
# 2                    Library of Congress Subject Headings
# 3                    Library of Congress Subject Headings
# 4       Fictional Space in the Modernist and Post-mode...
#                               ...
# 2044                                       The Index Card
# 2045                                   The Road to Wealth
# 2046                               The Success Principles
# 2047                               The Courage to Be Rich
# 2048                                     The Money Manual
# Name: title, Length: 2049, dtype: object

# %%
type(books_data.title)
# Out:
# pandas.core.series.Series

# %%
pd.Series([1, 2, 3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.DataFrame({
    "name": ["Michael", "Alice"],
    "age": [19, 20]
})
# Out:
#       name  age
# 0  Michael   19
# 1    Alice   20

# %%
books_data.dtypes
# Out:
# title             object
# author            object
# pages             object
# genre             object
# description       object
# published_date    object
# publisher         object
# language          object
# average_rating    object
# ratings_count      int64
# thumbnail         object
# dtype: object

# %%
books_data["pages"]
# Out:
# 0        252
# 1        802
# 2       1662
# 3       1512
# 4        248
#         ...
# 2044     256
# 2045     608
# 2046     512
# 2047     448
# 2048     256
# Name: pages, Length: 2049, dtype: object

# %%
books_data.pages
# Out:
# 0        252
# 1        802
# 2       1662
# 3       1512
# 4        248
#         ...
# 2044     256
# 2045     608
# 2046     512
# 2047     448
# 2048     256
# Name: pages, Length: 2049, dtype: object

# %%
books_data.genre
# Out:
# 0                          Literary Criticism
# 1                                   Reference
# 2       Subject headings, Library of Congress
# 3       Subject headings, Library of Congress
# 4                                     Fiction
#                         ...
# 2044                         Personal Finance
# 2045                         Personal Finance
# 2046                                Self-Help
# 2047                         Personal Finance
# 2048                         Personal Finance
# Name: genre, Length: 2049, dtype: object

# %%
books_data.pages.unique()
# Out:
# array(['252', '802', '1662', '1512', '248', '337', '384', '230', '178',
#        '692', '604', '206', '838', '314', '64', '234', '644', '224',
#        '652', '104', '1082', '1592', '1112', '780', '370', '254', '526',
#        '562', '32', '194', '896', '268', '82', '196', '160', '882', '242',
#        '816', '1306', '122', '134', '290', '282', '172', '204', '142',
#        '40', '102', '136', '130', '164', '238', '156', '144', '132',
#        '212', '150', '298', '107', '138', '148', '250', '152', '886',
#        '800', '522', '814', '332', '2131', '303', '200', '267', '528',
#        '382', '309', '670', '222', '624', '490', '608', '554', '805',
#        '18', '596', '112', '1525', '400', '654', '71', '432', '538',
#        '1034', '872', '636', '368', '85', '244', '2936', '322', '440',
#        '416', '316', '472', '513', '928', '1900', '498', '1816', '372',
#        '296', '628', '1448', '80', '84', '189', '1735', '243', '304',
# ...

# %%
books_data.pages.astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 books_data.pages.astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
# ...

# %%
books_data.pages.replace("Unknown", np.nan)
# Out:
# 0        252
# 1        802
# 2       1662
# 3       1512
# 4        248
#         ...
# 2044     256
# 2045     608
# 2046     512
# 2047     448
# 2048     256
# Name: pages, Length: 2049, dtype: object

# %%
books_data.pages.replace("Unknown", np.nan, inplace = True)

# %%
books_data.pages = books_data.pages.replace("Unknown", np.nan)

# %%
books_data.pages.astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 books_data.pages.astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
# ...

# %%
books_data.pages.astype(float)
# Out:
# 0        252.0
# 1        802.0
# 2       1662.0
# 3       1512.0
# 4        248.0
#          ...
# 2044     256.0
# 2045     608.0
# 2046     512.0
# 2047     448.0
# 2048     256.0
# Name: pages, Length: 2049, dtype: float64

# %%
books_data = pd.read_csv("data/books-dataset/Books.csv", na_values = ["Unknown"])

# %%
books_data
# Out:
#                                                   title  \
# 0                              Fictional Points of View
# 1                Science Fiction and Fantasy Literature
# 2                  Library of Congress Subject Headings
# 3                  Library of Congress Subject Headings
# 4     Fictional Space in the Modernist and Post-mode...
# ...                                                 ...
# 2044                                     The Index Card
# 2045                                 The Road to Wealth
# 2046                             The Success Principles
# 2047                             The Courage to Be Rich
# 2048                                   The Money Manual
#
#                                                  author   pages  \
# 0                                        Peter Lamarque   252.0
# 1        R. Reginald, Douglas Menville, Mary A. Burgess   802.0
# 2     Library of Congress. Cataloging Policy and Sup...  1662.0
# ...

# %%
books_data.dtypes
# Out:
# title              object
# author             object
# pages             float64
# genre              object
# description        object
# published_date     object
# publisher          object
# language           object
# average_rating     object
# ratings_count       int64
# thumbnail          object
# dtype: object

# %%
books_data = pd.read_csv("data/books-dataset/Books.csv", 
                         na_values = ["Unknown"], true_values = ["yes", 1), false_values = ["no", 0]

# %%
books_data
# Out:
#                                                   title  \
# 0                              Fictional Points of View
# 1                Science Fiction and Fantasy Literature
# 2                  Library of Congress Subject Headings
# 3                  Library of Congress Subject Headings
# 4     Fictional Space in the Modernist and Post-mode...
# ...                                                 ...
# 2044                                     The Index Card
# 2045                                 The Road to Wealth
# 2046                             The Success Principles
# 2047                             The Courage to Be Rich
# 2048                                   The Money Manual
#
#                                                  author   pages  \
# 0                                        Peter Lamarque   252.0
# 1        R. Reginald, Douglas Menville, Mary A. Burgess   802.0
# 2     Library of Congress. Cataloging Policy and Sup...  1662.0
# ...
